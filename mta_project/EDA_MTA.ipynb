# %% [markdown]
# # Exploratory Data Analysis with Python
#
# We will explore the NYC MTA turnstile data set. These data files are from the New York Subway. It tracks the hourly entries and exits to turnstiles (UNIT) by day in the subway system.
#
# Here is an [example of what you could do with the data](https://jameskao.me/analyzing-the-nyc-subway-dataset/). James Kao investigates how subway ridership is affected by incidence of rain.

# %% [markdown]
# ## Exercise 1
#
# - Download a few [MTA turnstile data files](http://web.mta.info/developers/turnstile.html)
# - Open up a file, use csv reader to read it, make a python dict where there is a key for each (C/A, UNIT, SCP, STATION). These are the first four columns. The value for this key should be a list of lists. Each list in the list is the rest of the columns in a row. For example, one key-value pair should look like
#
#
#         {    ('A002','R051','02-00-00','LEXINGTON AVE'):
#              [
#                ['NQR456', 'BMT', '01/03/2015', '03:00:00', 'REGULAR', '0004945474', '0001675324'],
#                  ['NQR456', 'BMT', '01/03/2015', '07:00:00', 'REGULAR', '0004945478', '0001675333'],
#                 ['NQR456', 'BMT', '01/03/2015', '11:00:00', 'REGULAR', '0004945515', '0001675364'],
#               ...
#          ]
#         }

# %%
import csv
import datetime
import calendar
import matplotlib.pyplot as plt
import dateutil.parser
from pprint import pprint
from collections import defaultdict

f1 = csv.reader(open("turnstile_161231.txt", 'r'))
f2 = csv.reader(open("turnstile_170107.txt", 'r'))
final_list1 = [[cell.strip() for cell in row] for row in f1] #remove whitespace from beginning and end of string
final_list2 = [[cell.strip() for cell in row] for row in f2]

# %%
final_list1 = final_list1[1:len(final_list)]

# %%
final_list2 = final_list2[1:len(final_list2)]

# %%
# creating dictionary using first 4 elements as key and remaining elements as list of values
mydict = defaultdict(list)
for row in final_list1:
    dictkey = tuple(row[0:4])
    dictvalue = row[4:-1]
    if dictkey in mydict:
        mydict[dictkey].append(dictvalue)
    else:
        mydict[dictkey] = [dictvalue]

# %%
pprint(mydict[('R253', 'R181', '00-00-02', '110 ST')][:5])
# Out:
# [['6', 'IRT', '12/24/2016', '03:00:00', 'REGULAR', '0004661223'],
#  ['6', 'IRT', '12/24/2016', '07:00:00', 'REGULAR', '0004661237'],
#  ['6', 'IRT', '12/24/2016', '11:00:00', 'REGULAR', '0004661301'],
#  ['6', 'IRT', '12/24/2016', '15:00:00', 'REGULAR', '0004661442'],
#  ['6', 'IRT', '12/24/2016', '19:00:00', 'REGULAR', '0004661636']]

# %% [markdown]
# ## Exercise 2
# - Let's turn this into a time series.
#
#  For each key (basically the control area, unit, device address and station of a specific turnstile), have a list again, but let the list be comprised of just the point in time and the cumulative count of entries.
#
# This basically means keeping only the date, time, and entries fields in each list. You can convert the date and time into datetime objects -- That is a python class that represents a point in time. You can combine the date and time fields into a string and use the [dateutil](https://dateutil.readthedocs.io/en/stable/) module to convert it into a datetime object.
#
# Your new dict should look something like
#
#     {    ('A002','R051','02-00-00','LEXINGTON AVE'):
#              [
#                 [datetime.datetime(2013, 3, 2, 3, 0), 3788],
#                 [datetime.datetime(2013, 3, 2, 7, 0), 2585],
#                 [datetime.datetime(2013, 3, 2, 12, 0), 10653],
#                 [datetime.datetime(2013, 3, 2, 17, 0), 11016],
#                 [datetime.datetime(2013, 3, 2, 23, 0), 10666],
#                 [datetime.datetime(2013, 3, 3, 3, 0), 10814],
#                 [datetime.datetime(2013, 3, 3, 7, 0), 10229],
#                 ...
#               ],
#      ....
#      }

# %%
# create time series using datetime str and cumulative entries as values
mydict2 = defaultdict(list)

for row in final_list1:
    dict2key = tuple(row[0:4])
    datetime_string = row[6] + ' ' + row[7]
    entries = int(row[9])
    dict2val = [dateutil.parser.parse(datetime_string),entries]
    if dict2key in mydict2:
        mydict2[dict2key].append(dict2val)
    else:
        mydict2[dict2key] = [dict2val]

# %%
pprint(mydict2[('R253', 'R181', '00-00-02', '110 ST')][:5])
# Out:
# [[datetime.datetime(2016, 12, 24, 3, 0), 4661223],
#  [datetime.datetime(2016, 12, 24, 7, 0), 4661237],
#  [datetime.datetime(2016, 12, 24, 11, 0), 4661301],
#  [datetime.datetime(2016, 12, 24, 15, 0), 4661442],
#  [datetime.datetime(2016, 12, 24, 19, 0), 4661636]]

# %% [markdown]
# ## Exercise 3
# - These counts are cumulative every n hours. We want total daily entries.
#
# Now make it that we again have the same keys, but now we have a single value for a single day, which is not cumulative counts but the total number of passengers that entered through this turnstile on this day.

# %%
dict3 = defaultdict(list)
temp_dict = defaultdict(list)

# create dictionary for each turnstile daily with total entry count
# first create temp dictionary with date and append entry cum number
# then create a new value which is max cum number mins min cum number
# assign this value to new key of second dictionary
for row in final_list1:
    temp_key = (row[0],row[1],row[2],row[3], dateutil.parser.parse(row[6])) #creates temporary key with date
    entries = int(row[9])
    temp_dict[temp_key].append(entries)
for k,v in temp_dict.items():
    delta = max(v) - min(v)
    dict3key = k[0:4]
    dict3value = (k[4], delta)
    dict3[dict3key].append(dict3value)

# %%
pprint(dict3[('R253', 'R181', '00-00-02', '110 ST')])
# Out:
# [(datetime.datetime(2016, 12, 29, 0, 0), 613),
#  (datetime.datetime(2016, 12, 25, 0, 0), 380),
#  (datetime.datetime(2016, 12, 27, 0, 0), 679),
#  (datetime.datetime(2016, 12, 28, 0, 0), 779),
#  (datetime.datetime(2016, 12, 30, 0, 0), 802),
#  (datetime.datetime(2016, 12, 24, 0, 0), 571),
#  (datetime.datetime(2016, 12, 26, 0, 0), 463)]

# %%
dict3_file2 = defaultdict(list)
temp3_file2 = defaultdict(list)

# create dictionary for each turnstile daily with total entry count
# first create temp dictionary with date and append entry cum number
# then create a new value which is max cum number mins min cum number
# assign this value to new key of second dictionary
for row in final_list2:
    temp3_key = (row[0],row[1],row[2],row[3], dateutil.parser.parse(row[6])) #creates temporary key with date
    entries = int(row[9])
    temp3_file2[temp3_key].append(entries)
for k,v in temp3_file2.items():
    delta = max(v) - min(v)
    dict3_file2key = k[0:4]
    dict3_file2value = (k[4], delta)
    dict3_file2[dict3_file2key].append(dict3_file2value)

# %%
pprint(dict3[('A002', 'R051', '02-00-00', '59 ST')])
# Out:
# [(datetime.datetime(2016, 12, 27, 0, 0), 1518),
#  (datetime.datetime(2016, 12, 29, 0, 0), 1940),
#  (datetime.datetime(2016, 12, 28, 0, 0), 2333),
#  (datetime.datetime(2016, 12, 24, 0, 0), 1030),
#  (datetime.datetime(2016, 12, 30, 0, 0), 2329),
#  (datetime.datetime(2016, 12, 26, 0, 0), 1004),
#  (datetime.datetime(2016, 12, 25, 0, 0), 427)]

# %%
pprint(dict3_file2[('A002', 'R051', '02-00-00', '59 ST')])
# Out:
# [(datetime.datetime(2017, 1, 5, 0, 0), 1702),
#  (datetime.datetime(2017, 1, 3, 0, 0), 1715),
#  (datetime.datetime(2017, 1, 2, 0, 0), 907),
#  (datetime.datetime(2017, 1, 4, 0, 0), 1602),
#  (datetime.datetime(2016, 12, 31, 0, 0), 1092),
#  (datetime.datetime(2017, 1, 1, 0, 0), 797),
#  (datetime.datetime(2017, 1, 6, 0, 0), 1609)]

# %% [markdown]
# # Exercise 4
# - We will plot the daily time series for a turnstile.
#
# In ipython notebook, add this to the beginning of your next cell:
#
#     %matplotlib inline
#
# This will make your matplotlib graphs integrate nicely with the notebook.
# To plot the time series, import matplotlib with
#
#     import matplotlib.pyplot as plt
#
# Take the list of [(date1, count1), (date2, count2), ...], for the turnstile and turn it into two lists:
# dates and counts. This should plot it:
#
#     plt.figure(figsize=(10,3))
#     plt.plot(dates,counts)

# %%
# %matplotlib inline

dates = []
counts = []

# take one turnstile and append dates and count from values
firstpair = {k: dict3[k] for k in list(dict3.keys())[:1]}
for v in firstpair.values():
    for date,count in v:
        dates.append(date)
        counts.append(count)
        
plt.figure(figsize=(10,3))
plt.plot(dates, counts, 'ro')
plt.title('Station {} Time Series'.format(firstpair.keys()))
plt.xlabel('Date')
plt.ylabel('Daily Entries')

# %%
# %matplotlib inline

dates2 = []
counts2 = []

# take one turnstile and append dates and count from values
pair2 = {k: dict3_file2[k] for k in list(dict3_file2.keys())[:1]}
for v in pair2.values():
    for date,count in v:
        dates2.append(date)
        counts2.append(count)
        
plt.figure(figsize=(10,3))
plt.plot(dates2, counts2, 'ro')
plt.title('Station {} Time Series'.format(pair2.keys()))
plt.xlabel('Date')
plt.ylabel('Daily Entries')

# %% [markdown]
# ## Exercise 5
# - So far we've been operating on a single turnstile level, let's combine turnstiles in the same ControlArea/Unit/Station combo. There are some ControlArea/Unit/Station groups that have a single turnstile, but most have multiple turnstilea-- same value for the C/A, UNIT and STATION columns, different values for the SCP column.
#
# We want to combine the numbers together -- for each ControlArea/UNIT/STATION combo, for each day, add the counts from each turnstile belonging to that combo.

# %%
temp_dict = defaultdict(list)

# new key with ControlArea/Unit/Station and date
for key, value in dict3.items():
    for date, count in value:
        temp_key = (key[0],key[1],key[3],date)
        temp_value = (count)
        temp_dict[temp_key].append(temp_value)
        
# create new dictionary minus date
# value becomes date and entry sum    
dict4 = defaultdict(list)
for key, value in temp_dict.items():
    dict4_key = (key[0],key[1],key[2])
    dict4[dict4_key].append((key[3],sum(value)))

# %%
pprint(dict4[('A002', 'R051', '59 ST')])
# Out:
# [(datetime.datetime(2016, 12, 25, 0, 0), 3844),
#  (datetime.datetime(2016, 12, 27, 0, 0), 14724),
#  (datetime.datetime(2016, 12, 24, 0, 0), 6658),
#  (datetime.datetime(2016, 12, 29, 0, 0), 14902),
#  (datetime.datetime(2016, 12, 26, 0, 0), 8629),
#  (datetime.datetime(2016, 12, 28, 0, 0), 16068),
#  (datetime.datetime(2016, 12, 30, 0, 0), 15149)]

# %%
temp4_file2 = defaultdict(list)

# new key with ControlArea/Unit/Station and date
for key, value in dict3_file2.items():
    for date, count in value:
        temp4_2key = (key[0],key[1],key[3],date)
        temp4_2value = (count)
        temp4_file2[temp4_2key].append(temp4_2value)
    
# create new dictionary minus date
# value becomes date and entry sum
dict4_file2 = defaultdict(list)
for key, value in temp4_file2.items():
    dict4_file2key = (key[0],key[1],key[2])
    dict4_file2[dict4_file2key].append((key[3],sum(value)))

# %%
pprint(dict4_file2[('A002', 'R051', '59 ST')])
# Out:
# [(datetime.datetime(2017, 1, 5, 0, 0), 15345),
#  (datetime.datetime(2017, 1, 4, 0, 0), 15162),
#  (datetime.datetime(2017, 1, 3, 0, 0), 14746),
#  (datetime.datetime(2017, 1, 1, 0, 0), 5990),
#  (datetime.datetime(2017, 1, 6, 0, 0), 14709),
#  (datetime.datetime(2017, 1, 2, 0, 0), 7685),
#  (datetime.datetime(2016, 12, 31, 0, 0), 7509)]

# %% [markdown]
# ## Exercise 6
# - Similarly, combine everything in each station, and come up with a time series of `[(date1, count1),(date2,count2),...]` type of time series for each STATION, by adding up all the turnstiles in a station.

# %%
temp_dict = defaultdict(list)

# create temp key with date added and setting value to the count
for key, value in dict4.items():
    for date, count in value:
        temp_key = (key[2],date)
        temp_value = (count)
        temp_dict[temp_key].append(temp_value)

# bring back to original dictionary with station only
# value becomes date and sum of entries
dict5 = defaultdict(list)
for key, value in temp_dict.items():
    dict5key = (key[0])
    dict5[dict5key].append((key[1], sum(value)))

pprint(dict5)
# Out:
# defaultdict(<class 'list'>,
#             {'1 AV': [(datetime.datetime(2016, 12, 24, 0, 0), 8173),
#                       (datetime.datetime(2016, 12, 26, 0, 0), 8243),
#                       (datetime.datetime(2016, 12, 30, 0, 0), 17865),
#                       (datetime.datetime(2016, 12, 27, 0, 0), 14492),
#                       (datetime.datetime(2016, 12, 25, 0, 0), 5489),
#                       (datetime.datetime(2016, 12, 29, 0, 0), 16649),
#                       (datetime.datetime(2016, 12, 28, 0, 0), 16268)],
#              '103 ST': [(datetime.datetime(2016, 12, 29, 0, 0), 25270),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 26423),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 15648),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 15961),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 23653),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 11203),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 25840)],
#              '103 ST-CORONA': [(datetime.datetime(2016, 12, 25, 0, 0), 8151),
#                                (datetime.datetime(2016, 12, 26, 0, 0), 13410),
#                                (datetime.datetime(2016, 12, 29, 0, 0), 17436),
#                                (datetime.datetime(2016, 12, 28, 0, 0), 18650),
#                                (datetime.datetime(2016, 12, 30, 0, 0), 18658),
#                                (datetime.datetime(2016, 12, 24, 0, 0), 12483),
#                                (datetime.datetime(2016, 12, 27, 0, 0), 18342)],
#              '104 ST': [(datetime.datetime(2016, 12, 28, 0, 0), 3977),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 3658),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 3690),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 2277),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 2133),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 1399),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 3902)],
#              '110 ST': [(datetime.datetime(2016, 12, 29, 0, 0), 9550),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 6567),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 10513),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 9923),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 6228),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 4219),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 9342)],
#              '111 ST': [(datetime.datetime(2016, 12, 26, 0, 0), 10091),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 9552),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 14757),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 14088),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 6058),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 14962),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 14650)],
#              '116 ST': [(datetime.datetime(2016, 12, 26, 0, 0), 16772),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 17672),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 25589),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 12377),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 27191),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 25232),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 28097)],
#              '116 ST-COLUMBIA': [(datetime.datetime(2016, 12, 29, 0, 0), 6355),
#                                  (datetime.datetime(2016, 12, 30, 0, 0), 6394),
#                                  (datetime.datetime(2016, 12, 24, 0, 0), 3125),
#                                  (datetime.datetime(2016, 12, 27, 0, 0), 5120),
#                                  (datetime.datetime(2016, 12, 26, 0, 0), 3223),
#                                  (datetime.datetime(2016, 12, 25, 0, 0), 2749),
#                                  (datetime.datetime(2016, 12, 28, 0, 0), 6685)],
#              '121 ST': [(datetime.datetime(2016, 12, 28, 0, 0), 2162),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 951),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 2095),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 1336),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 2162),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 1400),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 1990)],
#              '125 ST': [(datetime.datetime(2016, 12, 27, 0, 0), 59362),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 37271),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 39407),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 59314),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 65860),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 63780),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 27373)],
#              '135 ST': [(datetime.datetime(2016, 12, 29, 0, 0), 15711),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 16945),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 9617),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 15162),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 9310),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 7365),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 17121)],
#              '137 ST CITY COL': [(datetime.datetime(2016, 12, 30, 0, 0), 10167),
#                                  (datetime.datetime(2016, 12, 25, 0, 0), 4288),
#                                  (datetime.datetime(2016, 12, 26, 0, 0), 6459),
#                                  (datetime.datetime(2016, 12, 28, 0, 0), 9384),
#                                  (datetime.datetime(2016, 12, 27, 0, 0), 9307),
#                                  (datetime.datetime(2016, 12, 24, 0, 0), 6310),
#                                  (datetime.datetime(2016, 12, 29, 0, 0), 9524)],
#              '138/GRAND CONC': [(datetime.datetime(2016, 12, 26, 0, 0), 1366),
#                                 (datetime.datetime(2016, 12, 25, 0, 0), 778),
#                                 (datetime.datetime(2016, 12, 29, 0, 0), 2760),
#                                 (datetime.datetime(2016, 12, 30, 0, 0), 2803),
#                                 (datetime.datetime(2016, 12, 28, 0, 0), 2885),
#                                 (datetime.datetime(2016, 12, 27, 0, 0), 2934),
#                                 (datetime.datetime(2016, 12, 24, 0, 0), 1382)],
#              '14 ST': [(datetime.datetime(2016, 12, 25, 0, 0), 11781),
#                        (datetime.datetime(2016, 12, 30, 0, 0), 45879),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 45998),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 22350),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 24026),
#                        (datetime.datetime(2016, 12, 27, 0, 0), 41723),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 43340)],
#              '14 ST-UNION SQ': [(datetime.datetime(2016, 12, 26, 0, 0), 39715),
#                                 (datetime.datetime(2016, 12, 29, 0, 0), 64417),
#                                 (datetime.datetime(2016, 12, 25, 0, 0), 19347),
#                                 (datetime.datetime(2016, 12, 27, 0, 0), 64954),
#                                 (datetime.datetime(2016, 12, 28, 0, 0), 71305),
#                                 (datetime.datetime(2016, 12, 24, 0, 0), 45323),
#                                 (datetime.datetime(2016, 12, 30, 0, 0), 74048)],
#              '145 ST': [(datetime.datetime(2016, 12, 27, 0, 0), 28029),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 20652),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 31835),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 13600),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 19212),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 30310),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 29244)],
#              '149/GRAND CONC': [(datetime.datetime(2016, 12, 27, 0, 0), 9667),
#                                 (datetime.datetime(2016, 12, 29, 0, 0), 9253),
#                                 (datetime.datetime(2016, 12, 30, 0, 0), 9080),
#                                 (datetime.datetime(2016, 12, 25, 0, 0), 3425),
#                                 (datetime.datetime(2016, 12, 24, 0, 0), 5813),
#                                 (datetime.datetime(2016, 12, 26, 0, 0), 5603),
#                                 (datetime.datetime(2016, 12, 28, 0, 0), 9790)],
#              '14TH STREET': [(datetime.datetime(2016, 12, 29, 0, 0), 5123),
#                              (datetime.datetime(2016, 12, 28, 0, 0), 6720),
#                              (datetime.datetime(2016, 12, 27, 0, 0), 5871),
#                              (datetime.datetime(2016, 12, 25, 0, 0), 1387),
#                              (datetime.datetime(2016, 12, 26, 0, 0), 2209),
#                              (datetime.datetime(2016, 12, 24, 0, 0), 2253),
#                              (datetime.datetime(2016, 12, 30, 0, 0), 6045)],
#              '15 ST-PROSPECT': [(datetime.datetime(2016, 12, 29, 0, 0), 4242),
#                                 (datetime.datetime(2016, 12, 25, 0, 0), 1251),
#                                 (datetime.datetime(2016, 12, 28, 0, 0), 4429),
#                                 (datetime.datetime(2016, 12, 24, 0, 0), 1945),
#                                 (datetime.datetime(2016, 12, 27, 0, 0), 3838),
#                                 (datetime.datetime(2016, 12, 30, 0, 0), 4275),
#                                 (datetime.datetime(2016, 12, 26, 0, 0), 2260)],
#              '155 ST': [(datetime.datetime(2016, 12, 24, 0, 0), 3722),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 5173),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 5291),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 3667),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 5522),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 2706),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 5634)],
#              '157 ST': [(datetime.datetime(2016, 12, 28, 0, 0), 8388),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 9245),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 8457),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 6145),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 6144),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 3900),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 8405)],
#              '161/YANKEE STAD': [(datetime.datetime(2016, 12, 26, 0, 0), 13116),
#                                  (datetime.datetime(2016, 12, 29, 0, 0), 19275),
#                                  (datetime.datetime(2016, 12, 28, 0, 0), 30240),
#                                  (datetime.datetime(2016, 12, 25, 0, 0), 8563),
#                                  (datetime.datetime(2016, 12, 30, 0, 0), 20842),
#                                  (datetime.datetime(2016, 12, 27, 0, 0), 20412),
#                                  (datetime.datetime(2016, 12, 24, 0, 0),
#                                   12494)],
#              '163 ST-AMSTERDM': [(datetime.datetime(2016, 12, 29, 0, 0), 1715),
#                                  (datetime.datetime(2016, 12, 25, 0, 0), 1466),
#                                  (datetime.datetime(2016, 12, 30, 0, 0), 3806),
#                                  (datetime.datetime(2016, 12, 27, 0, 0), 3456),
#                                  (datetime.datetime(2016, 12, 26, 0, 0), 2427),
#                                  (datetime.datetime(2016, 12, 28, 0, 0), 2032),
#                                  (datetime.datetime(2016, 12, 24, 0, 0), 2412)],
#              '167 ST': [(datetime.datetime(2016, 12, 27, 0, 0), 17554),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 11919),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 17196),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 12565),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 8568),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 9763),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 17906)],
#              '168 ST': [(datetime.datetime(2016, 12, 26, 0, 0), 10431),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 9626),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 6739),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 19352),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 19837),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 20041),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 18375)],
#              '169 ST': [(datetime.datetime(2016, 12, 27, 0, 0), 7477),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 4637),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 4496),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 6893),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 7512),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 7238),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 3148)],
#              '170 ST': [(datetime.datetime(2016, 12, 30, 0, 0), 14517),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 9693),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 12986),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 13786),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 13835),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 9843),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 6441)],
#              '174 ST': [(datetime.datetime(2016, 12, 27, 0, 0), 5995),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 6163),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 5707),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 2648),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 4026),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 3604),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 6165)],
#              '174-175 STS': [(datetime.datetime(2016, 12, 28, 0, 0), 4988),
#                              (datetime.datetime(2016, 12, 25, 0, 0), 2319),
#                              (datetime.datetime(2016, 12, 27, 0, 0), 4893),
#                              (datetime.datetime(2016, 12, 24, 0, 0), 3002),
#                              (datetime.datetime(2016, 12, 30, 0, 0), 5072),
#                              (datetime.datetime(2016, 12, 26, 0, 0), 3114),
#                              (datetime.datetime(2016, 12, 29, 0, 0), 4707)],
#              '175 ST': [(datetime.datetime(2016, 12, 29, 0, 0), 10700),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 5691),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 4309),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 11606),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 11557),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 11156),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 7111)],
#              '176 ST': [(datetime.datetime(2016, 12, 29, 0, 0), 5024),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 5386),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 5078),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 5591),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 3680),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 2634),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 3778)],
#              '18 AV': [(datetime.datetime(2016, 12, 30, 0, 0), 11090),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 10659),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 5543),
#                        (datetime.datetime(2016, 12, 27, 0, 0), 11620),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 6390),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 7827),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 11799)],
#              '18 ST': [(datetime.datetime(2016, 12, 30, 0, 0), 6086),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 890),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 2842),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 5862),
#                        (datetime.datetime(2016, 12, 27, 0, 0), 5518),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 2449),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 6015)],
#              '181 ST': [(datetime.datetime(2016, 12, 25, 0, 0), 8073),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 19284),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 18130),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 19607),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 18265),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 11753),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 12848)],
#              '182-183 STS': [(datetime.datetime(2016, 12, 24, 0, 0), 2846),
#                              (datetime.datetime(2016, 12, 30, 0, 0), 4595),
#                              (datetime.datetime(2016, 12, 26, 0, 0), 3276),
#                              (datetime.datetime(2016, 12, 28, 0, 0), 4510),
#                              (datetime.datetime(2016, 12, 29, 0, 0), 4197),
#                              (datetime.datetime(2016, 12, 27, 0, 0), 4500),
#                              (datetime.datetime(2016, 12, 25, 0, 0), 2315)],
#              '183 ST': [(datetime.datetime(2016, 12, 26, 0, 0), 3856),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 5607),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 5290),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 4100),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 5548),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 5340),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 2616)],
#              '190 ST': [(datetime.datetime(2016, 12, 28, 0, 0), 3953),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 2088),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 3790),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 3458),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 3563),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 1355),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 1841)],
#              '191 ST': [(datetime.datetime(2016, 12, 24, 0, 0), 4799),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 6931),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 3336),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 7246),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 6884),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 7131),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 5161)],
#              '2 AV': [(datetime.datetime(2016, 12, 30, 0, 0), 16294),
#                       (datetime.datetime(2016, 12, 29, 0, 0), 14752),
#                       (datetime.datetime(2016, 12, 24, 0, 0), 7896),
#                       (datetime.datetime(2016, 12, 28, 0, 0), 14786),
#                       (datetime.datetime(2016, 12, 27, 0, 0), 12798),
#                       (datetime.datetime(2016, 12, 26, 0, 0), 8117),
#                       (datetime.datetime(2016, 12, 25, 0, 0), 5516)],
#              '20 AV': [(datetime.datetime(2016, 12, 30, 0, 0), 5432),
#                        (datetime.datetime(2016, 12, 27, 0, 0), 5423),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 2735),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 3964),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 5156),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 5496),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 3344)],
#              '207 ST': [(datetime.datetime(2016, 12, 28, 0, 0), 5587),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 2652),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 6030),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 5376),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 4106),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 5555),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 3880)],
#              '21 ST': [(datetime.datetime(2016, 12, 30, 0, 0), 1367),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 1344),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 324),
#                        (datetime.datetime(2016, 12, 27, 0, 0), 1219),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 1227),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 548),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 585)],
#              '21 ST-QNSBRIDGE': [(datetime.datetime(2016, 12, 25, 0, 0), 3488),
#                                  (datetime.datetime(2016, 12, 26, 0, 0), 3971),
#                                  (datetime.datetime(2016, 12, 29, 0, 0), 8079),
#                                  (datetime.datetime(2016, 12, 27, 0, 0), 7959),
#                                  (datetime.datetime(2016, 12, 24, 0, 0), 4524),
#                                  (datetime.datetime(2016, 12, 28, 0, 0), 8596),
#                                  (datetime.datetime(2016, 12, 30, 0, 0), 8511)],
#              '215 ST': [(datetime.datetime(2016, 12, 27, 0, 0), 1589),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 826),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 535),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 871),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 1458),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 1583),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 1512)],
#              '219 ST': [(datetime.datetime(2016, 12, 29, 0, 0), 2613),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 1774),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 2803),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 2747),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 1684),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 2760),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 1165)],
#              '225 ST': [(datetime.datetime(2016, 12, 25, 0, 0), 1510),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 2221),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 3503),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 3582),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 2302),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 3283),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 3520)],
#              '23 ST': [(datetime.datetime(2016, 12, 26, 0, 0), 38335),
#                        (datetime.datetime(2016, 12, 27, 0, 0), 75805),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 18636),
#                        (datetime.datetime(2016, 12, 30, 0, 0), 80607),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 79707),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 33278),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 85237)],
#              '231 ST': [(datetime.datetime(2016, 12, 26, 0, 0), 5735),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 8440),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 8076),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 3485),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 8528),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 5122),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 8689)],
#              '233 ST': [(datetime.datetime(2016, 12, 26, 0, 0), 2631),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 3855),
#                         (datetime.datetime(2016, 12, 28, 0, 0), 4240),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 1695),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 4204),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 2622),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 4254)],
#              '238 ST': [(datetime.datetime(2016, 12, 28, 0, 0), 3715),
#                         (datetime.datetime(2016, 12, 30, 0, 0), 3623),
#                         (datetime.datetime(2016, 12, 26, 0, 0), 2080),
#                         (datetime.datetime(2016, 12, 29, 0, 0), 3335),
#                         (datetime.datetime(2016, 12, 24, 0, 0), 1813),
#                         (datetime.datetime(2016, 12, 25, 0, 0), 1297),
#                         (datetime.datetime(2016, 12, 27, 0, 0), 3545)],
#              '25 AV': [(datetime.datetime(2016, 12, 28, 0, 0), 5476),
#                        (datetime.datetime(2016, 12, 27, 0, 0), 5395),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 2954),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 2297),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 3514),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 5099),
#                        (datetime.datetime(2016, 12, 30, 0, 0), 5266)],
#              '25 ST': [(datetime.datetime(2016, 12, 24, 0, 0), 1542),
#                        (datetime.datetime(2016, 12, 30, 0, 0), 3342),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 3146),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 3114),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 1157),
#                        (datetime.datetime(2016, 12, 27, 0, 0), 2939),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 1859)],
#              '28 ST': [(datetime.datetime(2016, 12, 27, 0, 0), 32291),
#                        (datetime.datetime(2016, 12, 30, 0, 0), 34305),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 35246),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 9495),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 15548),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 35963),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 13917)],
#              '3 AV': [(datetime.datetime(2016, 12, 25, 0, 0), 1618),
#                       (datetime.datetime(2016, 12, 30, 0, 0), 5832),
#                       (datetime.datetime(2016, 12, 27, 0, 0), 4654),
#                       (datetime.datetime(2016, 12, 29, 0, 0), 5248),
#                       (datetime.datetime(2016, 12, 26, 0, 0), 2834),
#                       (datetime.datetime(2016, 12, 28, 0, 0), 5216),
#                       (datetime.datetime(2016, 12, 24, 0, 0), 2742)],
#              '3 AV 138 ST': [(datetime.datetime(2016, 12, 25, 0, 0), 2525),
#                              (datetime.datetime(2016, 12, 27, 0, 0), 6139),
#                              (datetime.datetime(2016, 12, 24, 0, 0), 3652),
#                              (datetime.datetime(2016, 12, 26, 0, 0), 3822),
#                              (datetime.datetime(2016, 12, 30, 0, 0), 6258),
#                              (datetime.datetime(2016, 12, 29, 0, 0), 6211),
#                              (datetime.datetime(2016, 12, 28, 0, 0), 6220)],
#              '3 AV-149 ST': [(datetime.datetime(2016, 12, 29, 0, 0), 19576),
#                              (datetime.datetime(2016, 12, 24, 0, 0), 12755),
#                              (datetime.datetime(2016, 12, 30, 0, 0), 21882),
#                              (datetime.datetime(2016, 12, 27, 0, 0), 19892),
#                              (datetime.datetime(2016, 12, 28, 0, 0), 20426),
#                              (datetime.datetime(2016, 12, 25, 0, 0), 8036),
#                              (datetime.datetime(2016, 12, 26, 0, 0), 12582)],
#              '30 AV': [(datetime.datetime(2016, 12, 27, 0, 0), 10546),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 11286),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 6201),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 4094),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 11323),
#                        (datetime.datetime(2016, 12, 30, 0, 0), 11892),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 6329)],
#              '33 ST': [(datetime.datetime(2016, 12, 27, 0, 0), 20825),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 23994),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 5346),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 22514),
#                        (datetime.datetime(2016, 12, 30, 0, 0), 21895),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 8059),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 9042)],
#              '33 ST-RAWSON ST': [(datetime.datetime(2016, 12, 25, 0, 0), 791),
#                                  (datetime.datetime(2016, 12, 26, 0, 0), 2177),
#                                  (datetime.datetime(2016, 12, 28, 0, 0), 6974),
#                                  (datetime.datetime(2016, 12, 30, 0, 0), 5253),
#                                  (datetime.datetime(2016, 12, 27, 0, 0), 6753),
#                                  (datetime.datetime(2016, 12, 24, 0, 0), 1418),
#                                  (datetime.datetime(2016, 12, 29, 0, 0), 6579)],
#              '34 ST-HERALD SQ': [(datetime.datetime(2016, 12, 28, 0, 0),
#                                   124710),
#                                  (datetime.datetime(2016, 12, 27, 0, 0),
#                                   117300),
#                                  (datetime.datetime(2016, 12, 24, 0, 0), 61412),
#                                  (datetime.datetime(2016, 12, 29, 0, 0),
#                                   112806),
#                                  (datetime.datetime(2016, 12, 30, 0, 0),
#                                   120308),
#                                  (datetime.datetime(2016, 12, 25, 0, 0), 38919),
#                                  (datetime.datetime(2016, 12, 26, 0, 0),
#                                   78649)],
#              '34 ST-HUDSON YD': [(datetime.datetime(2016, 12, 29, 0, 0), 6118),
#                                  (datetime.datetime(2016, 12, 26, 0, 0), 2926),
#                                  (datetime.datetime(2016, 12, 30, 0, 0), 6258),
#                                  (datetime.datetime(2016, 12, 27, 0, 0), 6628),
#                                  (datetime.datetime(2016, 12, 24, 0, 0), 1905),
#                                  (datetime.datetime(2016, 12, 28, 0, 0), 7284),
#                                  (datetime.datetime(2016, 12, 25, 0, 0), 2159)],
#              '34 ST-PENN STA': [(datetime.datetime(2016, 12, 30, 0, 0), 143484),
#                                 (datetime.datetime(2016, 12, 27, 0, 0), 145962),
#                                 (datetime.datetime(2016, 12, 28, 0, 0), 156159),
#                                 (datetime.datetime(2016, 12, 24, 0, 0), 60890),
#                                 (datetime.datetime(2016, 12, 29, 0, 0), 139061),
#                                 (datetime.datetime(2016, 12, 26, 0, 0), 90461),
#                                 (datetime.datetime(2016, 12, 25, 0, 0), 44475)],
#              '36 AV': [(datetime.datetime(2016, 12, 26, 0, 0), 3449),
#                        (datetime.datetime(2016, 12, 30, 0, 0), 5937),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 5785),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 2171),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 3283),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 5450),
#                        (datetime.datetime(2016, 12, 27, 0, 0), 5336)],
#              '36 ST': [(datetime.datetime(2016, 12, 24, 0, 0), 6759),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 13825),
#                        (datetime.datetime(2016, 12, 27, 0, 0), 14144),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 3657),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 7538),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 14529),
#                        (datetime.datetime(2016, 12, 30, 0, 0), 13824)],
#              '39 AV': [(datetime.datetime(2016, 12, 29, 0, 0), 3008),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 1190),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 1410),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 3091),
#                        (datetime.datetime(2016, 12, 27, 0, 0), 2925),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 1823),
#                        (datetime.datetime(2016, 12, 30, 0, 0), 2989)],
#              '4 AV-9 ST': [(datetime.datetime(2016, 12, 25, 0, 0), 710),
#                            (datetime.datetime(2016, 12, 27, 0, 0), 2631),
#                            (datetime.datetime(2016, 12, 26, 0, 0), 1550),
#                            (datetime.datetime(2016, 12, 28, 0, 0), 2834),
#                            (datetime.datetime(2016, 12, 29, 0, 0), 2799),
#                            (datetime.datetime(2016, 12, 24, 0, 0), 1355),
#                            (datetime.datetime(2016, 12, 30, 0, 0), 3098)],
#              '40 ST LOWERY ST': [(datetime.datetime(2016, 12, 28, 0, 0), 8841),
#                                  (datetime.datetime(2016, 12, 26, 0, 0), 5184),
#                                  (datetime.datetime(2016, 12, 25, 0, 0), 3334),
#                                  (datetime.datetime(2016, 12, 29, 0, 0), 8420),
#                                  (datetime.datetime(2016, 12, 30, 0, 0), 8613),
#                                  (datetime.datetime(2016, 12, 27, 0, 0), 8669),
#                                  (datetime.datetime(2016, 12, 24, 0, 0), 5000)],
#              '42 ST-BRYANT PK': [(datetime.datetime(2016, 12, 29, 0, 0), 34197),
#                                  (datetime.datetime(2016, 12, 25, 0, 0), 15469),
#                                  (datetime.datetime(2016, 12, 24, 0, 0), 14120),
#                                  (datetime.datetime(2016, 12, 28, 0, 0), 40638),
#                                  (datetime.datetime(2016, 12, 27, 0, 0), 38208),
#                                  (datetime.datetime(2016, 12, 26, 0, 0), 17217),
#                                  (datetime.datetime(2016, 12, 30, 0, 0),
#                                   36404)],
#              '42 ST-PORT AUTH': [(datetime.datetime(2016, 12, 25, 0, 0), 37382),
#                                  (datetime.datetime(2016, 12, 30, 0, 0), 90955),
#                                  (datetime.datetime(2016, 12, 27, 0, 0), 86608),
#                                  (datetime.datetime(2016, 12, 29, 0, 0), 89197),
#                                  (datetime.datetime(2016, 12, 24, 0, 0), 44245),
#                                  (datetime.datetime(2016, 12, 28, 0, 0), 94934),
#                                  (datetime.datetime(2016, 12, 26, 0, 0),
#                                   59034)],
#              '45 ST': [(datetime.datetime(2016, 12, 24, 0, 0), 3687),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 4146),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 2533),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 5681),
#                        (datetime.datetime(2016, 12, 30, 0, 0), 6092),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 5908),
#                        (datetime.datetime(2016, 12, 27, 0, 0), 47389)],
#              '46 ST': [(datetime.datetime(2016, 12, 30, 0, 0), 7115),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 7285),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 4146),
#                        (datetime.datetime(2016, 12, 27, 0, 0), 6788),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 2303),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 4037),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 6831)],
#              '46 ST BLISS ST': [(datetime.datetime(2016, 12, 24, 0, 0), 8043),
#                                 (datetime.datetime(2016, 12, 25, 0, 0), 5438),
#                                 (datetime.datetime(2016, 12, 29, 0, 0), 11640),
#                                 (datetime.datetime(2016, 12, 28, 0, 0), 12040),
#                                 (datetime.datetime(2016, 12, 26, 0, 0), 7872),
#                                 (datetime.datetime(2016, 12, 27, 0, 0), 11640),
#                                 (datetime.datetime(2016, 12, 30, 0, 0), 12284)],
#              '47-50 STS ROCK': [(datetime.datetime(2016, 12, 25, 0, 0), 35594),
#                                 (datetime.datetime(2016, 12, 28, 0, 0), 72832),
#                                 (datetime.datetime(2016, 12, 24, 0, 0), 28776),
#                                 (datetime.datetime(2016, 12, 30, 0, 0), 65905),
#                                 (datetime.datetime(2016, 12, 27, 0, 0), 66572),
#                                 (datetime.datetime(2016, 12, 29, 0, 0), 59365),
#                                 (datetime.datetime(2016, 12, 26, 0, 0), 34185)],
#              '49 ST': [(datetime.datetime(2016, 12, 27, 0, 0), 25964),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 14533),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 18931),
#                        (datetime.datetime(2016, 12, 30, 0, 0), 28062),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 15594),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 25182),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 29000)],
#              '4AV-9 ST': [(datetime.datetime(2016, 12, 28, 0, 0), 6961),
#                           (datetime.datetime(2016, 12, 27, 0, 0), 6466),
#                           (datetime.datetime(2016, 12, 26, 0, 0), 3628),
#                           (datetime.datetime(2016, 12, 24, 0, 0), 3175),
#                           (datetime.datetime(2016, 12, 30, 0, 0), 7172),
#                           (datetime.datetime(2016, 12, 29, 0, 0), 6672),
#                           (datetime.datetime(2016, 12, 25, 0, 0), 1962)],
#              '5 AV/53 ST': [(datetime.datetime(2016, 12, 28, 0, 0), 24739),
#                             (datetime.datetime(2016, 12, 25, 0, 0), 5540),
#                             (datetime.datetime(2016, 12, 26, 0, 0), 9071),
#                             (datetime.datetime(2016, 12, 24, 0, 0), 7718),
#                             (datetime.datetime(2016, 12, 29, 0, 0), 23076),
#                             (datetime.datetime(2016, 12, 27, 0, 0), 21777),
#                             (datetime.datetime(2016, 12, 30, 0, 0), 23605)],
#              '5 AV/59 ST': [(datetime.datetime(2016, 12, 29, 0, 0), 14400),
#                             (datetime.datetime(2016, 12, 30, 0, 0), 16622),
#                             (datetime.datetime(2016, 12, 27, 0, 0), 17030),
#                             (datetime.datetime(2016, 12, 26, 0, 0), 10786),
#                             (datetime.datetime(2016, 12, 28, 0, 0), 17541),
#                             (datetime.datetime(2016, 12, 25, 0, 0), 9533),
#                             (datetime.datetime(2016, 12, 24, 0, 0), 8073)],
#              '5 AVE': [(datetime.datetime(2016, 12, 25, 0, 0), 5445),
#                        (datetime.datetime(2016, 12, 27, 0, 0), 985994219),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 13607),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 11681),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 7046),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 5325),
#                        (datetime.datetime(2016, 12, 30, 0, 0), 12237)],
#              '50 ST': [(datetime.datetime(2016, 12, 25, 0, 0), 20077),
#                        (datetime.datetime(2016, 12, 30, 0, 0), 47544),
#                        (datetime.datetime(2016, 12, 27, 0, 0), 43117),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 48871),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 45050),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 27399),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 22060)],
#              '51 ST': [(datetime.datetime(2016, 12, 26, 0, 0), 10800),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 7586),
#                        (datetime.datetime(2016, 12, 27, 0, 0), 19512),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 21069),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 19186),
#                        (datetime.datetime(2016, 12, 30, 0, 0), 19461),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 8936)],
#              '52 ST': [(datetime.datetime(2016, 12, 29, 0, 0), 5338),
#                        (datetime.datetime(2016, 12, 27, 0, 0), 5270),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 3408),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 3396),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 2337),
#                        (datetime.datetime(2016, 12, 30, 0, 0), 5542),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 5541)],
#              '53 ST': [(datetime.datetime(2016, 12, 28, 0, 0), 6483),
#                        (datetime.datetime(2016, 12, 27, 0, 0), 6433),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 6195),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 3963),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 2772),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 4339),
#                        (datetime.datetime(2016, 12, 30, 0, 0), 6434)],
#              '55 ST': [(datetime.datetime(2016, 12, 27, 0, 0), 2105),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 2308),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 1454),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 695),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 768),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 2125),
#                        (datetime.datetime(2016, 12, 30, 0, 0), 1755)],
#              '57 ST': [(datetime.datetime(2016, 12, 27, 0, 0), 12579),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 6028),
#                        (datetime.datetime(2016, 12, 30, 0, 0), 6759),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 6334),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 12176),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 13516),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 5586)],
#              '57 ST-7 AV': [(datetime.datetime(2016, 12, 26, 0, 0), 15162),
#                             (datetime.datetime(2016, 12, 24, 0, 0), 12508),
#                             (datetime.datetime(2016, 12, 30, 0, 0), 23651),
#                             (datetime.datetime(2016, 12, 28, 0, 0), 25663),
#                             (datetime.datetime(2016, 12, 29, 0, 0), 23461),
#                             (datetime.datetime(2016, 12, 25, 0, 0), 9840),
#                             (datetime.datetime(2016, 12, 27, 0, 0), 23695)],
#              '59 ST': [(datetime.datetime(2016, 12, 29, 0, 0), 65137),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 17972),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 70686),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 32665),
#                        (datetime.datetime(2016, 12, 30, 0, 0), 67046),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 39826),
#                        (datetime.datetime(2016, 12, 27, 0, 0), 66567)],
#              '59 ST COLUMBUS': [(datetime.datetime(2016, 12, 25, 0, 0), 21374),
#                                 (datetime.datetime(2016, 12, 30, 0, 0), 56430),
#                                 (datetime.datetime(2016, 12, 29, 0, 0), 53283),
#                                 (datetime.datetime(2016, 12, 26, 0, 0), 32309),
#                                 (datetime.datetime(2016, 12, 24, 0, 0), 29851),
#                                 (datetime.datetime(2016, 12, 28, 0, 0), 57932),
#                                 (datetime.datetime(2016, 12, 27, 0, 0), 53259)],
#              '6 AV': [(datetime.datetime(2016, 12, 24, 0, 0), 2257),
#                       (datetime.datetime(2016, 12, 26, 0, 0), 2554),
#                       (datetime.datetime(2016, 12, 27, 0, 0), 4193),
#                       (datetime.datetime(2016, 12, 29, 0, 0), 4528),
#                       (datetime.datetime(2016, 12, 30, 0, 0), 4883),
#                       (datetime.datetime(2016, 12, 28, 0, 0), 4678),
#                       (datetime.datetime(2016, 12, 25, 0, 0), 1184)],
#              '61 ST WOODSIDE': [(datetime.datetime(2016, 12, 29, 0, 0), 13171),
#                                 (datetime.datetime(2016, 12, 25, 0, 0), 6148),
#                                 (datetime.datetime(2016, 12, 26, 0, 0), 8779),
#                                 (datetime.datetime(2016, 12, 27, 0, 0), 13595),
#                                 (datetime.datetime(2016, 12, 28, 0, 0), 13568),
#                                 (datetime.datetime(2016, 12, 24, 0, 0), 8197),
#                                 (datetime.datetime(2016, 12, 30, 0, 0), 13595)],
#              '63 DR-REGO PARK': [(datetime.datetime(2016, 12, 24, 0, 0), 9352),
#                                  (datetime.datetime(2016, 12, 30, 0, 0), 15461),
#                                  (datetime.datetime(2016, 12, 27, 0, 0), 14960),
#                                  (datetime.datetime(2016, 12, 29, 0, 0), 14688),
#                                  (datetime.datetime(2016, 12, 28, 0, 0), 16084),
#                                  (datetime.datetime(2016, 12, 25, 0, 0), 4832),
#                                  (datetime.datetime(2016, 12, 26, 0, 0), 9930)],
#              '65 ST': [(datetime.datetime(2016, 12, 27, 0, 0), 3182),
#                        (datetime.datetime(2016, 12, 24, 0, 0), 1960),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 3125),
#                        (datetime.datetime(2016, 12, 28, 0, 0), 3231),
#                        (datetime.datetime(2016, 12, 30, 0, 0), 3241),
#                        (datetime.datetime(2016, 12, 25, 0, 0), 1261),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 2294)],
#              '66 ST-LINCOLN': [(datetime.datetime(2016, 12, 28, 0, 0), 16331),
#                                (datetime.datetime(2016, 12, 24, 0, 0), 9724),
#                                (datetime.datetime(2016, 12, 27, 0, 0), 14660),
#                                (datetime.datetime(2016, 12, 25, 0, 0), 5322),
#                                (datetime.datetime(2016, 12, 29, 0, 0), 16746),
#                                (datetime.datetime(2016, 12, 26, 0, 0), 9684),
#                                (datetime.datetime(2016, 12, 30, 0, 0), 16327)],
#              '67 AV': [(datetime.datetime(2016, 12, 28, 0, 0), 7734),
#                        (datetime.datetime(2016, 12, 26, 0, 0), 3929),
#                        (datetime.datetime(2016, 12, 29, 0, 0), 7363),
# ...
#                               (datetime.datetime(2016, 12, 25, 0, 0), 1536),
#                               (datetime.datetime(2016, 12, 30, 0, 0), 3696),
#                               (datetime.datetime(2016, 12, 29, 0, 0), 3697)],
#              'SUTPHIN-ARCHER': [(datetime.datetime(2016, 12, 24, 0, 0), 13402),
#                                 (datetime.datetime(2016, 12, 27, 0, 0), 22311),
#                                 (datetime.datetime(2016, 12, 26, 0, 0), 15351),
#                                 (datetime.datetime(2016, 12, 28, 0, 0), 23027),
#                                 (datetime.datetime(2016, 12, 30, 0, 0), 22862),
#                                 (datetime.datetime(2016, 12, 29, 0, 0), 22366),
#                                 (datetime.datetime(2016, 12, 25, 0, 0), 10660)],
#              'SUTTER AV': [(datetime.datetime(2016, 12, 27, 0, 0), 3512),
#                            (datetime.datetime(2016, 12, 30, 0, 0), 3874),
#                            (datetime.datetime(2016, 12, 28, 0, 0), 3636),
#                            (datetime.datetime(2016, 12, 29, 0, 0), 3443),
#                            (datetime.datetime(2016, 12, 25, 0, 0), 1767),
#                            (datetime.datetime(2016, 12, 24, 0, 0), 2395),
#                            (datetime.datetime(2016, 12, 26, 0, 0), 2360)],
#              'THIRTY ST': [(datetime.datetime(2016, 12, 29, 0, 0), 6076),
#                            (datetime.datetime(2016, 12, 28, 0, 0), 8083),
#                            (datetime.datetime(2016, 12, 27, 0, 0), 7620),
#                            (datetime.datetime(2016, 12, 24, 0, 0), 1322),
#                            (datetime.datetime(2016, 12, 25, 0, 0), 3188),
#                            (datetime.datetime(2016, 12, 30, 0, 0), 6935),
#                            (datetime.datetime(2016, 12, 26, 0, 0), 3545)],
#              'THIRTY THIRD ST': [(datetime.datetime(2016, 12, 27, 0, 0), 17629),
#                                  (datetime.datetime(2016, 12, 29, 0, 0), 15470),
#                                  (datetime.datetime(2016, 12, 25, 0, 0), 8050),
#                                  (datetime.datetime(2016, 12, 26, 0, 0), 8632),
#                                  (datetime.datetime(2016, 12, 30, 0, 0), 16375),
#                                  (datetime.datetime(2016, 12, 28, 0, 0), 19873),
#                                  (datetime.datetime(2016, 12, 24, 0, 0), 7593)],
#              'TIMES SQ-42 ST': [(datetime.datetime(2016, 12, 30, 0, 0), 89190),
#                                 (datetime.datetime(2016, 12, 25, 0, 0), 46766),
#                                 (datetime.datetime(2016, 12, 27, 0, 0), 86227),
#                                 (datetime.datetime(2016, 12, 24, 0, 0), 45646),
#                                 (datetime.datetime(2016, 12, 29, 0, 0), 83058),
#                                 (datetime.datetime(2016, 12, 28, 0, 0), 94498),
#                                 (datetime.datetime(2016, 12, 26, 0, 0), 58280)],
#              'TOMPKINSVILLE': [(datetime.datetime(2016, 12, 27, 0, 0), 624),
#                                (datetime.datetime(2016, 12, 26, 0, 0), 350),
#                                (datetime.datetime(2016, 12, 30, 0, 0), 617),
#                                (datetime.datetime(2016, 12, 28, 0, 0), 594),
#                                (datetime.datetime(2016, 12, 24, 0, 0), 348),
#                                (datetime.datetime(2016, 12, 29, 0, 0), 552),
#                                (datetime.datetime(2016, 12, 25, 0, 0), 153)],
#              'TREMONT AV': [(datetime.datetime(2016, 12, 28, 0, 0), 8791),
#                             (datetime.datetime(2016, 12, 29, 0, 0), 8158),
#                             (datetime.datetime(2016, 12, 25, 0, 0), 3736),
#                             (datetime.datetime(2016, 12, 24, 0, 0), 5079),
#                             (datetime.datetime(2016, 12, 30, 0, 0), 8725),
#                             (datetime.datetime(2016, 12, 27, 0, 0), 8359),
#                             (datetime.datetime(2016, 12, 26, 0, 0), 5529)],
#              'TWENTY THIRD ST': [(datetime.datetime(2016, 12, 28, 0, 0), 6058),
#                                  (datetime.datetime(2016, 12, 25, 0, 0), 1039),
#                                  (datetime.datetime(2016, 12, 24, 0, 0), 1159),
#                                  (datetime.datetime(2016, 12, 26, 0, 0), 1589),
#                                  (datetime.datetime(2016, 12, 29, 0, 0), 5152),
#                                  (datetime.datetime(2016, 12, 27, 0, 0), 5868),
#                                  (datetime.datetime(2016, 12, 30, 0, 0), 5214)],
#              'UNION ST': [(datetime.datetime(2016, 12, 30, 0, 0), 4708),
#                           (datetime.datetime(2016, 12, 24, 0, 0), 2022),
#                           (datetime.datetime(2016, 12, 27, 0, 0), 4124),
#                           (datetime.datetime(2016, 12, 29, 0, 0), 4710),
#                           (datetime.datetime(2016, 12, 26, 0, 0), 2290),
#                           (datetime.datetime(2016, 12, 28, 0, 0), 4626),
#                           (datetime.datetime(2016, 12, 25, 0, 0), 1252)],
#              'UTICA AV': [(datetime.datetime(2016, 12, 28, 0, 0), 12340),
#                           (datetime.datetime(2016, 12, 29, 0, 0), 11975),
#                           (datetime.datetime(2016, 12, 30, 0, 0), 12881),
#                           (datetime.datetime(2016, 12, 26, 0, 0), 7492),
#                           (datetime.datetime(2016, 12, 24, 0, 0), 7852),
#                           (datetime.datetime(2016, 12, 27, 0, 0), 11694),
#                           (datetime.datetime(2016, 12, 25, 0, 0), 5221)],
#              'V.CORTLANDT PK': [(datetime.datetime(2016, 12, 28, 0, 0), 6101),
#                                 (datetime.datetime(2016, 12, 27, 0, 0), 6074),
#                                 (datetime.datetime(2016, 12, 26, 0, 0), 3769),
#                                 (datetime.datetime(2016, 12, 25, 0, 0), 2116),
#                                 (datetime.datetime(2016, 12, 29, 0, 0), 5587),
#                                 (datetime.datetime(2016, 12, 24, 0, 0), 3074),
#                                 (datetime.datetime(2016, 12, 30, 0, 0), 5978)],
#              'VAN SICLEN AV': [(datetime.datetime(2016, 12, 25, 0, 0), 3147),
#                                (datetime.datetime(2016, 12, 30, 0, 0), 7531),
#                                (datetime.datetime(2016, 12, 28, 0, 0), 7497),
#                                (datetime.datetime(2016, 12, 24, 0, 0), 4749),
#                                (datetime.datetime(2016, 12, 27, 0, 0), 7243),
#                                (datetime.datetime(2016, 12, 26, 0, 0), 4703),
#                                (datetime.datetime(2016, 12, 29, 0, 0), 7023)],
#              'VAN SICLEN AVE': [(datetime.datetime(2016, 12, 27, 0, 0), 2417),
#                                 (datetime.datetime(2016, 12, 30, 0, 0), 2712),
#                                 (datetime.datetime(2016, 12, 28, 0, 0), 2576),
#                                 (datetime.datetime(2016, 12, 26, 0, 0), 1629),
#                                 (datetime.datetime(2016, 12, 29, 0, 0), 2407),
#                                 (datetime.datetime(2016, 12, 25, 0, 0), 1230),
#                                 (datetime.datetime(2016, 12, 24, 0, 0), 1674)],
#              'VERNON-JACKSON': [(datetime.datetime(2016, 12, 28, 0, 0), 12132),
#                                 (datetime.datetime(2016, 12, 24, 0, 0), 5541),
#                                 (datetime.datetime(2016, 12, 30, 0, 0), 12045),
#                                 (datetime.datetime(2016, 12, 29, 0, 0), 11252),
#                                 (datetime.datetime(2016, 12, 27, 0, 0), 11307),
#                                 (datetime.datetime(2016, 12, 26, 0, 0), 5959),
#                                 (datetime.datetime(2016, 12, 25, 0, 0), 3852)],
#              'W 4 ST-WASH SQ': [(datetime.datetime(2016, 12, 27, 0, 0), 22674),
#                                 (datetime.datetime(2016, 12, 29, 0, 0), 24049),
#                                 (datetime.datetime(2016, 12, 30, 0, 0), 27092),
#                                 (datetime.datetime(2016, 12, 25, 0, 0), 9244),
#                                 (datetime.datetime(2016, 12, 24, 0, 0), 14584),
#                                 (datetime.datetime(2016, 12, 28, 0, 0), 25467),
#                                 (datetime.datetime(2016, 12, 26, 0, 0), 13206)],
#              'W 8 ST-AQUARIUM': [(datetime.datetime(2016, 12, 24, 0, 0), 675),
#                                  (datetime.datetime(2016, 12, 28, 0, 0), 1971),
#                                  (datetime.datetime(2016, 12, 29, 0, 0), 1756),
#                                  (datetime.datetime(2016, 12, 25, 0, 0), 671),
#                                  (datetime.datetime(2016, 12, 27, 0, 0), 1907),
#                                  (datetime.datetime(2016, 12, 30, 0, 0), 1909),
#                                  (datetime.datetime(2016, 12, 26, 0, 0), 1001)],
#              'WAKEFIELD/241': [(datetime.datetime(2016, 12, 24, 0, 0), 2725),
#                                (datetime.datetime(2016, 12, 27, 0, 0), 4290),
#                                (datetime.datetime(2016, 12, 26, 0, 0), 2690),
#                                (datetime.datetime(2016, 12, 29, 0, 0), 4024),
#                                (datetime.datetime(2016, 12, 25, 0, 0), 1883),
#                                (datetime.datetime(2016, 12, 30, 0, 0), 4253),
#                                (datetime.datetime(2016, 12, 28, 0, 0), 4358)],
#              'WALL ST': [(datetime.datetime(2016, 12, 30, 0, 0), 29686),
#                          (datetime.datetime(2016, 12, 24, 0, 0), 6886),
#                          (datetime.datetime(2016, 12, 25, 0, 0), 5767),
#                          (datetime.datetime(2016, 12, 29, 0, 0), 31566),
#                          (datetime.datetime(2016, 12, 27, 0, 0), 31715),
#                          (datetime.datetime(2016, 12, 28, 0, 0), 35454),
#                          (datetime.datetime(2016, 12, 26, 0, 0), 9219)],
#              'WEST FARMS SQ': [(datetime.datetime(2016, 12, 24, 0, 0), 3580),
#                                (datetime.datetime(2016, 12, 26, 0, 0), 3970),
#                                (datetime.datetime(2016, 12, 30, 0, 0), 6062),
#                                (datetime.datetime(2016, 12, 29, 0, 0), 5588),
#                                (datetime.datetime(2016, 12, 28, 0, 0), 6559),
#                                (datetime.datetime(2016, 12, 27, 0, 0), 6041),
#                                (datetime.datetime(2016, 12, 25, 0, 0), 2843)],
#              'WESTCHESTER SQ': [(datetime.datetime(2016, 12, 27, 0, 0), 5179),
#                                 (datetime.datetime(2016, 12, 28, 0, 0), 5324),
#                                 (datetime.datetime(2016, 12, 25, 0, 0), 1540),
#                                 (datetime.datetime(2016, 12, 30, 0, 0), 5033),
#                                 (datetime.datetime(2016, 12, 24, 0, 0), 2258),
#                                 (datetime.datetime(2016, 12, 29, 0, 0), 4961),
#                                 (datetime.datetime(2016, 12, 26, 0, 0), 2574)],
#              'WHITEHALL S-FRY': [(datetime.datetime(2016, 12, 25, 0, 0), 4916),
#                                  (datetime.datetime(2016, 12, 28, 0, 0), 16293),
#                                  (datetime.datetime(2016, 12, 26, 0, 0), 7065),
#                                  (datetime.datetime(2016, 12, 30, 0, 0), 15033),
#                                  (datetime.datetime(2016, 12, 29, 0, 0), 12964),
#                                  (datetime.datetime(2016, 12, 24, 0, 0), 3762),
#                                  (datetime.datetime(2016, 12, 27, 0, 0),
#                                   15239)],
#              'WHITLOCK AV': [(datetime.datetime(2016, 12, 28, 0, 0), 1556),
#                              (datetime.datetime(2016, 12, 27, 0, 0), 1555),
#                              (datetime.datetime(2016, 12, 25, 0, 0), 682),
#                              (datetime.datetime(2016, 12, 30, 0, 0), 1570),
#                              (datetime.datetime(2016, 12, 24, 0, 0), 996),
#                              (datetime.datetime(2016, 12, 26, 0, 0), 919),
#                              (datetime.datetime(2016, 12, 29, 0, 0), 1439)],
#              'WILSON AV': [(datetime.datetime(2016, 12, 28, 0, 0), 3490),
#                            (datetime.datetime(2016, 12, 25, 0, 0), 1389),
#                            (datetime.datetime(2016, 12, 30, 0, 0), 3855),
#                            (datetime.datetime(2016, 12, 24, 0, 0), 2374),
#                            (datetime.datetime(2016, 12, 27, 0, 0), 3359),
#                            (datetime.datetime(2016, 12, 29, 0, 0), 3478),
#                            (datetime.datetime(2016, 12, 26, 0, 0), 2198)],
#              'WINTHROP ST': [(datetime.datetime(2016, 12, 28, 0, 0), 5552),
#                              (datetime.datetime(2016, 12, 25, 0, 0), 1485),
#                              (datetime.datetime(2016, 12, 27, 0, 0), 5138),
#                              (datetime.datetime(2016, 12, 30, 0, 0), 5430),
#                              (datetime.datetime(2016, 12, 24, 0, 0), 2349),
#                              (datetime.datetime(2016, 12, 26, 0, 0), 2563),
#                              (datetime.datetime(2016, 12, 29, 0, 0), 5227)],
#              'WOODHAVEN BLVD': [(datetime.datetime(2016, 12, 24, 0, 0), 19135),
#                                 (datetime.datetime(2016, 12, 29, 0, 0), 23152),
#                                 (datetime.datetime(2016, 12, 28, 0, 0), 25218),
#                                 (datetime.datetime(2016, 12, 25, 0, 0), 7701),
#                                 (datetime.datetime(2016, 12, 26, 0, 0), 18825),
#                                 (datetime.datetime(2016, 12, 27, 0, 0), 24840),
#                                 (datetime.datetime(2016, 12, 30, 0, 0), 24763)],
#              'WOODLAWN': [(datetime.datetime(2016, 12, 30, 0, 0), 6129),
#                           (datetime.datetime(2016, 12, 27, 0, 0), 6471),
#                           (datetime.datetime(2016, 12, 25, 0, 0), 1842),
#                           (datetime.datetime(2016, 12, 29, 0, 0), 6003),
#                           (datetime.datetime(2016, 12, 24, 0, 0), 3095),
#                           (datetime.datetime(2016, 12, 28, 0, 0), 6475),
#                           (datetime.datetime(2016, 12, 26, 0, 0), 3680)],
#              'WORLD TRADE CTR': [(datetime.datetime(2016, 12, 25, 0, 0), 6152),
#                                  (datetime.datetime(2016, 12, 27, 0, 0), 15536),
#                                  (datetime.datetime(2016, 12, 30, 0, 0), 15991),
#                                  (datetime.datetime(2016, 12, 28, 0, 0), 17118),
#                                  (datetime.datetime(2016, 12, 29, 0, 0), 14442),
#                                  (datetime.datetime(2016, 12, 26, 0, 0), 7448),
#                                  (datetime.datetime(2016, 12, 24, 0, 0), 5710)],
#              'YORK ST': [(datetime.datetime(2016, 12, 24, 0, 0), 2669),
#                          (datetime.datetime(2016, 12, 30, 0, 0), 7994),
#                          (datetime.datetime(2016, 12, 28, 0, 0), 7461),
#                          (datetime.datetime(2016, 12, 27, 0, 0), 6907),
#                          (datetime.datetime(2016, 12, 25, 0, 0), 3462),
#                          (datetime.datetime(2016, 12, 29, 0, 0), 6104),
#                          (datetime.datetime(2016, 12, 26, 0, 0), 3158)],
#              'ZEREGA AV': [(datetime.datetime(2016, 12, 29, 0, 0), 2046),
#                            (datetime.datetime(2016, 12, 28, 0, 0), 2129),
#                            (datetime.datetime(2016, 12, 27, 0, 0), 2074),
#                            (datetime.datetime(2016, 12, 30, 0, 0), 2044),
#                            (datetime.datetime(2016, 12, 24, 0, 0), 998),
#                            (datetime.datetime(2016, 12, 26, 0, 0), 1120),
#                            (datetime.datetime(2016, 12, 25, 0, 0), 749)]})

# %%
temp_dict = defaultdict(list)

# create temp key with date added and setting value to the count
for key, value in dict4_file2.items():
    for date, count in value:
        temp_key = (key[2],date)
        temp_value = (count)
        temp_dict[temp_key].append(temp_value)
# bring back to original dictionary with station only
# value becomes date and sum of entries
dict5_file2 = defaultdict(list)
for key, value in temp_dict.items():
    dict5_2key = (key[0])
    dict5_file2[dict5_2key].append((key[1], sum(value)))

pprint(dict5_file2)
# Out:
# defaultdict(<class 'list'>,
#             {'1 AV': [(datetime.datetime(2017, 1, 2, 0, 0), 11171),
#                       (datetime.datetime(2017, 1, 3, 0, 0), 20162),
#                       (datetime.datetime(2016, 12, 31, 0, 0), 13745),
#                       (datetime.datetime(2017, 1, 4, 0, 0), 21119),
#                       (datetime.datetime(2017, 1, 6, 0, 0), 21854),
#                       (datetime.datetime(2017, 1, 1, 0, 0), 9732),
#                       (datetime.datetime(2017, 1, 5, 0, 0), 21559)],
#              '103 ST': [(datetime.datetime(2017, 1, 5, 0, 0), 30924),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 30312),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 27388),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 16384),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 17846),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 28492),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 13531)],
#              '103 ST-CORONA': [(datetime.datetime(2017, 1, 6, 0, 0), 20330),
#                                (datetime.datetime(2017, 1, 1, 0, 0), 8250),
#                                (datetime.datetime(2017, 1, 5, 0, 0), 20036),
#                                (datetime.datetime(2016, 12, 31, 0, 0), 12981),
#                                (datetime.datetime(2017, 1, 4, 0, 0), 20370),
#                                (datetime.datetime(2017, 1, 3, 0, 0), 19183),
#                                (datetime.datetime(2017, 1, 2, 0, 0), 12556)],
#              '104 ST': [(datetime.datetime(2017, 1, 1, 0, 0), 1350),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 2165),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 4586),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 4584),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 4624),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 2181),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 4341)],
#              '110 ST': [(datetime.datetime(2016, 12, 31, 0, 0), 7502),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 4889),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 12508),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 11700),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 12453),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 12901),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 6340)],
#              '111 ST': [(datetime.datetime(2017, 1, 4, 0, 0), 16137),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 6381),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 16228),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 9313),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 15630),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 10056),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 16155)],
#              '116 ST': [(datetime.datetime(2017, 1, 2, 0, 0), 17934),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 33153),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 15344),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 34156),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 19568),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 33170),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 30668)],
#              '116 ST-COLUMBIA': [(datetime.datetime(2017, 1, 3, 0, 0), 6688),
#                                  (datetime.datetime(2017, 1, 1, 0, 0), 3468),
#                                  (datetime.datetime(2017, 1, 2, 0, 0), 3639),
#                                  (datetime.datetime(2017, 1, 4, 0, 0), 9518),
#                                  (datetime.datetime(2017, 1, 6, 0, 0), 9493),
#                                  (datetime.datetime(2016, 12, 31, 0, 0), 3553),
#                                  (datetime.datetime(2017, 1, 5, 0, 0), 9825)],
#              '121 ST': [(datetime.datetime(2016, 12, 31, 0, 0), 1425),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 992),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 2224),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 1269),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 2328),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 2339),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 2564)],
#              '125 ST': [(datetime.datetime(2017, 1, 4, 0, 0), 76696),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 33475),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 75957),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 76300),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 46563),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 38104),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 69452)],
#              '135 ST': [(datetime.datetime(2017, 1, 5, 0, 0), 20337),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 9952),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 20390),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 18604),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 11535),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 8670),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 20295)],
#              '137 ST CITY COL': [(datetime.datetime(2017, 1, 5, 0, 0), 12067),
#                                  (datetime.datetime(2017, 1, 4, 0, 0), 12342),
#                                  (datetime.datetime(2017, 1, 3, 0, 0), 11165),
#                                  (datetime.datetime(2017, 1, 1, 0, 0), 5553),
#                                  (datetime.datetime(2017, 1, 6, 0, 0), 11922),
#                                  (datetime.datetime(2016, 12, 31, 0, 0), 7290),
#                                  (datetime.datetime(2017, 1, 2, 0, 0), 6902)],
#              '138/GRAND CONC': [(datetime.datetime(2017, 1, 1, 0, 0), 929),
#                                 (datetime.datetime(2017, 1, 5, 0, 0), 3620),
#                                 (datetime.datetime(2017, 1, 2, 0, 0), 1298),
#                                 (datetime.datetime(2016, 12, 31, 0, 0), 1499),
#                                 (datetime.datetime(2017, 1, 6, 0, 0), 3536),
#                                 (datetime.datetime(2017, 1, 3, 0, 0), 3350),
#                                 (datetime.datetime(2017, 1, 4, 0, 0), 3688)],
#              '14 ST': [(datetime.datetime(2017, 1, 6, 0, 0), 58101),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 23645),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 28003),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 58437),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 59301),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 29734),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 54717)],
#              '14 ST-UNION SQ': [(datetime.datetime(2017, 1, 4, 0, 0), 86205),
#                                 (datetime.datetime(2017, 1, 1, 0, 0), 38318),
#                                 (datetime.datetime(2017, 1, 3, 0, 0), 77226),
#                                 (datetime.datetime(2016, 12, 31, 0, 0), 49100),
#                                 (datetime.datetime(2017, 1, 6, 0, 0), 85173),
#                                 (datetime.datetime(2017, 1, 2, 0, 0), 44867),
#                                 (datetime.datetime(2017, 1, 5, 0, 0), 84028)],
#              '145 ST': [(datetime.datetime(2017, 1, 5, 0, 0), 35355),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 32697),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 20900),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 25207),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 16961),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 35555),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 36170)],
#              '149/GRAND CONC': [(datetime.datetime(2017, 1, 4, 0, 0), 13507),
#                                 (datetime.datetime(2017, 1, 2, 0, 0), 5265),
#                                 (datetime.datetime(2017, 1, 1, 0, 0), 3807),
#                                 (datetime.datetime(2016, 12, 31, 0, 0), 5543),
#                                 (datetime.datetime(2017, 1, 6, 0, 0), 12868),
#                                 (datetime.datetime(2017, 1, 5, 0, 0), 13433),
#                                 (datetime.datetime(2017, 1, 3, 0, 0), 12338)],
#              '14TH STREET': [(datetime.datetime(2017, 1, 1, 0, 0), 2770),
#                              (datetime.datetime(2017, 1, 4, 0, 0), 8286),
#                              (datetime.datetime(2017, 1, 3, 0, 0), 7630),
#                              (datetime.datetime(2017, 1, 6, 0, 0), 7801),
#                              (datetime.datetime(2016, 12, 31, 0, 0), 3465),
#                              (datetime.datetime(2017, 1, 5, 0, 0), 7403),
#                              (datetime.datetime(2017, 1, 2, 0, 0), 2895)],
#              '15 ST-PROSPECT': [(datetime.datetime(2016, 12, 31, 0, 0), 2965),
#                                 (datetime.datetime(2017, 1, 3, 0, 0), 6036),
#                                 (datetime.datetime(2017, 1, 6, 0, 0), 6310),
#                                 (datetime.datetime(2017, 1, 5, 0, 0), 6446),
#                                 (datetime.datetime(2017, 1, 2, 0, 0), 2635),
#                                 (datetime.datetime(2017, 1, 1, 0, 0), 2149),
#                                 (datetime.datetime(2017, 1, 4, 0, 0), 6510)],
#              '155 ST': [(datetime.datetime(2017, 1, 2, 0, 0), 3735),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 6490),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 6534),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 6549),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 3968),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 6043),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 3279)],
#              '157 ST': [(datetime.datetime(2017, 1, 4, 0, 0), 10335),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 5146),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 10179),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 6497),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 6760),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 9379),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 10195)],
#              '161/YANKEE STAD': [(datetime.datetime(2016, 12, 31, 0, 0), 13188),
#                                  (datetime.datetime(2017, 1, 1, 0, 0), 9204),
#                                  (datetime.datetime(2017, 1, 5, 0, 0), 23421),
#                                  (datetime.datetime(2017, 1, 4, 0, 0), 23767),
#                                  (datetime.datetime(2017, 1, 2, 0, 0), 12658),
#                                  (datetime.datetime(2017, 1, 6, 0, 0), 23037),
#                                  (datetime.datetime(2017, 1, 3, 0, 0), 22194)],
#              '163 ST-AMSTERDM': [(datetime.datetime(2017, 1, 5, 0, 0), 4365),
#                                  (datetime.datetime(2017, 1, 4, 0, 0), 4257),
#                                  (datetime.datetime(2017, 1, 2, 0, 0), 2592),
#                                  (datetime.datetime(2016, 12, 31, 0, 0), 2628),
#                                  (datetime.datetime(2017, 1, 3, 0, 0), 4007),
#                                  (datetime.datetime(2017, 1, 6, 0, 0), 4300),
#                                  (datetime.datetime(2017, 1, 1, 0, 0), 2029)],
#              '167 ST': [(datetime.datetime(2017, 1, 3, 0, 0), 18791),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 20078),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 8715),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 11826),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 20284),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 12398),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 19958)],
#              '168 ST': [(datetime.datetime(2017, 1, 3, 0, 0), 20603),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 25475),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 11858),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 24968),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 8262),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 11421),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 24761)],
#              '169 ST': [(datetime.datetime(2017, 1, 4, 0, 0), 8767),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 4214),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 4778),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 8572),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 3172),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 8570),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 8184)],
#              '170 ST': [(datetime.datetime(2017, 1, 2, 0, 0), 8967),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 6328),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 15898),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 9464),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 16102),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 14676),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 16174)],
#              '174 ST': [(datetime.datetime(2017, 1, 1, 0, 0), 2706),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 7444),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 3862),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 7465),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 6917),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 7347),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 3745)],
#              '174-175 STS': [(datetime.datetime(2017, 1, 1, 0, 0), 2143),
#                              (datetime.datetime(2017, 1, 5, 0, 0), 5394),
#                              (datetime.datetime(2017, 1, 2, 0, 0), 2935),
#                              (datetime.datetime(2017, 1, 6, 0, 0), 5464),
#                              (datetime.datetime(2017, 1, 3, 0, 0), 5164),
#                              (datetime.datetime(2016, 12, 31, 0, 0), 2998),
#                              (datetime.datetime(2017, 1, 4, 0, 0), 5433)],
#              '175 ST': [(datetime.datetime(2017, 1, 1, 0, 0), 5128),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 11869),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 13461),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 6963),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 12949),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 7614),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 12950)],
#              '176 ST': [(datetime.datetime(2017, 1, 5, 0, 0), 6160),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 5985),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 3977),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 3503),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 6235),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 2606),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 6323)],
#              '18 AV': [(datetime.datetime(2016, 12, 31, 0, 0), 6567),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 12098),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 11886),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 12465),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 5010),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 7181),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 12725)],
#              '18 ST': [(datetime.datetime(2017, 1, 5, 0, 0), 8746),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 8734),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 8294),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 3207),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 2126),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 3528),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 7970)],
#              '181 ST': [(datetime.datetime(2017, 1, 1, 0, 0), 9737),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 22346),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 20692),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 13561),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 21720),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 22338),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 12877)],
#              '182-183 STS': [(datetime.datetime(2017, 1, 1, 0, 0), 2287),
#                              (datetime.datetime(2017, 1, 6, 0, 0), 5172),
#                              (datetime.datetime(2017, 1, 4, 0, 0), 5161),
#                              (datetime.datetime(2016, 12, 31, 0, 0), 3163),
#                              (datetime.datetime(2017, 1, 5, 0, 0), 5046),
#                              (datetime.datetime(2017, 1, 3, 0, 0), 4780),
#                              (datetime.datetime(2017, 1, 2, 0, 0), 3047)],
#              '183 ST': [(datetime.datetime(2017, 1, 5, 0, 0), 6328),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 6268),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 5714),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 4110),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 6381),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 2711),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 3701)],
#              '190 ST': [(datetime.datetime(2017, 1, 2, 0, 0), 2277),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 1721),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 4667),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 2613),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 4786),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 4208),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 4532)],
#              '191 ST': [(datetime.datetime(2017, 1, 6, 0, 0), 8636),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 8118),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 3858),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 8907),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 5232),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 8745),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 5010)],
#              '2 AV': [(datetime.datetime(2017, 1, 6, 0, 0), 17191),
#                       (datetime.datetime(2017, 1, 2, 0, 0), 10198),
#                       (datetime.datetime(2017, 1, 4, 0, 0), 16212),
#                       (datetime.datetime(2016, 12, 31, 0, 0), 12042),
#                       (datetime.datetime(2017, 1, 3, 0, 0), 15318),
#                       (datetime.datetime(2017, 1, 1, 0, 0), 9602),
#                       (datetime.datetime(2017, 1, 5, 0, 0), 16843)],
#              '20 AV': [(datetime.datetime(2017, 1, 5, 0, 0), 6132),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 3460),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 6144),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 2532),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 3404),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 5850),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 6170)],
#              '207 ST': [(datetime.datetime(2017, 1, 5, 0, 0), 6431),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 4448),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 2802),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 3928),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 6712),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 6611),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 5914)],
#              '21 ST': [(datetime.datetime(2017, 1, 4, 0, 0), 1546),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 792),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 216),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 635),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 900),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 1620),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 1430)],
#              '21 ST-QNSBRIDGE': [(datetime.datetime(2017, 1, 1, 0, 0), 3648),
#                                  (datetime.datetime(2017, 1, 3, 0, 0), 9034),
#                                  (datetime.datetime(2016, 12, 31, 0, 0), 5670),
#                                  (datetime.datetime(2017, 1, 5, 0, 0), 9598),
#                                  (datetime.datetime(2017, 1, 6, 0, 0), 9613),
#                                  (datetime.datetime(2017, 1, 4, 0, 0), 9590),
#                                  (datetime.datetime(2017, 1, 2, 0, 0), 4879)],
#              '215 ST': [(datetime.datetime(2016, 12, 31, 0, 0), 905),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 2065),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 629),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 1823),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 864),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 1952),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 2072)],
#              '219 ST': [(datetime.datetime(2017, 1, 2, 0, 0), 1634),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 1797),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 1277),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 3263),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 3239),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 3087),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 3381)],
#              '225 ST': [(datetime.datetime(2017, 1, 3, 0, 0), 4139),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 2365),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 12030794),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 2179),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 1654),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 4300),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 4428)],
#              '23 ST': [(datetime.datetime(2017, 1, 6, 0, 0), 109824),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 114505),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 44233),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 106920),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 113268),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 32775),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 45711)],
#              '231 ST': [(datetime.datetime(2017, 1, 2, 0, 0), 5294),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 8975),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 5781),
#                         (datetime.datetime(2017, 1, 1, 0, 0), 3909),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 10048),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 9727),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 10014)],
#              '233 ST': [(datetime.datetime(2017, 1, 1, 0, 0), 1844),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 4799),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 5078),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 4963),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 2626),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 2634),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 5044)],
#              '238 ST': [(datetime.datetime(2017, 1, 1, 0, 0), 1570),
#                         (datetime.datetime(2017, 1, 4, 0, 0), 4272),
#                         (datetime.datetime(2017, 1, 2, 0, 0), 2001),
#                         (datetime.datetime(2017, 1, 6, 0, 0), 4170),
#                         (datetime.datetime(2016, 12, 31, 0, 0), 2135),
#                         (datetime.datetime(2017, 1, 5, 0, 0), 4117),
#                         (datetime.datetime(2017, 1, 3, 0, 0), 3809)],
#              '25 AV': [(datetime.datetime(2016, 12, 31, 0, 0), 3119),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 6518),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 2404),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 6709),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 6763),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 6905),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 3249)],
#              '25 ST': [(datetime.datetime(2017, 1, 3, 0, 0), 3605),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 3614),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 2018),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 3613),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 2088),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 1349),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 3864)],
#              '28 ST': [(datetime.datetime(2016, 12, 31, 0, 0), 17699),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 17985),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 45778),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 14263),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 43478),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 44207),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 44015)],
#              '3 AV': [(datetime.datetime(2016, 12, 31, 0, 0), 4627),
#                       (datetime.datetime(2017, 1, 6, 0, 0), 6567),
#                       (datetime.datetime(2017, 1, 4, 0, 0), 6254),
#                       (datetime.datetime(2017, 1, 2, 0, 0), 4260),
#                       (datetime.datetime(2017, 1, 1, 0, 0), 3461),
#                       (datetime.datetime(2017, 1, 3, 0, 0), 6002),
#                       (datetime.datetime(2017, 1, 5, 0, 0), 6377)],
#              '3 AV 138 ST': [(datetime.datetime(2016, 12, 31, 0, 0), 3743),
#                              (datetime.datetime(2017, 1, 2, 0, 0), 3610),
#                              (datetime.datetime(2017, 1, 5, 0, 0), 7679),
#                              (datetime.datetime(2017, 1, 4, 0, 0), 7875),
#                              (datetime.datetime(2017, 1, 1, 0, 0), 2810),
#                              (datetime.datetime(2017, 1, 6, 0, 0), 7796),
#                              (datetime.datetime(2017, 1, 3, 0, 0), 7371)],
#              '3 AV-149 ST': [(datetime.datetime(2017, 1, 4, 0, 0), 24575),
#                              (datetime.datetime(2017, 1, 2, 0, 0), 11583),
#                              (datetime.datetime(2017, 1, 3, 0, 0), 22593),
#                              (datetime.datetime(2017, 1, 5, 0, 0), 24179),
#                              (datetime.datetime(2017, 1, 6, 0, 0), 24819),
#                              (datetime.datetime(2016, 12, 31, 0, 0), 12964),
#                              (datetime.datetime(2017, 1, 1, 0, 0), 7719)],
#              '30 AV': [(datetime.datetime(2017, 1, 3, 0, 0), 13298),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 14518),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 8309),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 7032),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 5352),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 14355),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 14214)],
#              '33 ST': [(datetime.datetime(2017, 1, 4, 0, 0), 27255),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 26558),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 10269),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 27863),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 8906),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 26599),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 11237)],
#              '33 ST-RAWSON ST': [(datetime.datetime(2017, 1, 6, 0, 0), 9751),
#                                  (datetime.datetime(2017, 1, 2, 0, 0), 2248),
#                                  (datetime.datetime(2017, 1, 5, 0, 0), 13086),
#                                  (datetime.datetime(2017, 1, 4, 0, 0), 12945),
#                                  (datetime.datetime(2016, 12, 31, 0, 0), 1754),
#                                  (datetime.datetime(2017, 1, 1, 0, 0), 1053),
#                                  (datetime.datetime(2017, 1, 3, 0, 0), 10804)],
#              '34 ST-HERALD SQ': [(datetime.datetime(2016, 12, 31, 0, 0), 66986),
#                                  (datetime.datetime(2017, 1, 5, 0, 0), 124548),
#                                  (datetime.datetime(2017, 1, 4, 0, 0), 126713),
#                                  (datetime.datetime(2017, 1, 2, 0, 0), 63703),
#                                  (datetime.datetime(2017, 1, 3, 0, 0), 117308),
#                                  (datetime.datetime(2017, 1, 6, 0, 0), 121667),
#                                  (datetime.datetime(2017, 1, 1, 0, 0), 49992)],
#              '34 ST-HUDSON YD': [(datetime.datetime(2016, 12, 31, 0, 0), 3579),
#                                  (datetime.datetime(2017, 1, 4, 0, 0), 8781),
#                                  (datetime.datetime(2017, 1, 1, 0, 0), 3164),
#                                  (datetime.datetime(2017, 1, 6, 0, 0), 8218),
#                                  (datetime.datetime(2017, 1, 3, 0, 0), 8088),
#                                  (datetime.datetime(2017, 1, 2, 0, 0), 3268),
#                                  (datetime.datetime(2017, 1, 5, 0, 0), 8883)],
#              '34 ST-PENN STA': [(datetime.datetime(2017, 1, 6, 0, 0), 160173),
#                                 (datetime.datetime(2017, 1, 5, 0, 0), 168288),
#                                 (datetime.datetime(2017, 1, 4, 0, 0), 167996),
#                                 (datetime.datetime(2017, 1, 2, 0, 0), 74738),
#                                 (datetime.datetime(2017, 1, 3, 0, 0), 66726864),
#                                 (datetime.datetime(2017, 1, 1, 0, 0), 59135),
#                                 (datetime.datetime(2016, 12, 31, 0, 0), 83615)],
#              '36 AV': [(datetime.datetime(2017, 1, 5, 0, 0), 6951),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 6846),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 7079),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 2697),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 3670),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 7011),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 3958)],
#              '36 ST': [(datetime.datetime(2016, 12, 31, 0, 0), 7546),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 17828),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 5112),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 17665),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 17766),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 16788),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 7196)],
#              '39 AV': [(datetime.datetime(2017, 1, 2, 0, 0), 1547),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 2908),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 2952),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 1383),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 1920),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 2996),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 2817)],
#              '4 AV-9 ST': [(datetime.datetime(2017, 1, 4, 0, 0), 3657),
#                            (datetime.datetime(2017, 1, 5, 0, 0), 3444),
#                            (datetime.datetime(2017, 1, 3, 0, 0), 3279),
#                            (datetime.datetime(2017, 1, 1, 0, 0), 1436),
#                            (datetime.datetime(2017, 1, 6, 0, 0), 3512),
#                            (datetime.datetime(2016, 12, 31, 0, 0), 2107),
#                            (datetime.datetime(2017, 1, 2, 0, 0), 1822)],
#              '40 ST LOWERY ST': [(datetime.datetime(2016, 12, 31, 0, 0), 6214),
#                                  (datetime.datetime(2017, 1, 6, 0, 0), 10476),
#                                  (datetime.datetime(2017, 1, 1, 0, 0), 3956),
#                                  (datetime.datetime(2017, 1, 2, 0, 0), 4991),
#                                  (datetime.datetime(2017, 1, 5, 0, 0), 10608),
#                                  (datetime.datetime(2017, 1, 4, 0, 0), 10695),
#                                  (datetime.datetime(2017, 1, 3, 0, 0), 10310)],
#              '42 ST-BRYANT PK': [(datetime.datetime(2017, 1, 3, 0, 0), 39139),
#                                  (datetime.datetime(2017, 1, 2, 0, 0), 13492),
#                                  (datetime.datetime(2017, 1, 4, 0, 0), 42925),
#                                  (datetime.datetime(2017, 1, 1, 0, 0), 13336),
#                                  (datetime.datetime(2016, 12, 31, 0, 0), 18800),
#                                  (datetime.datetime(2017, 1, 5, 0, 0), 42701),
#                                  (datetime.datetime(2017, 1, 6, 0, 0), 40082)],
#              '42 ST-PORT AUTH': [(datetime.datetime(2017, 1, 2, 0, 0), 54606),
#                                  (datetime.datetime(2017, 1, 5, 0, 0), 97633),
#                                  (datetime.datetime(2017, 1, 4, 0, 0), 95663),
#                                  (datetime.datetime(2016, 12, 31, 0, 0), 67116),
#                                  (datetime.datetime(2017, 1, 3, 0, 0), 97939),
#                                  (datetime.datetime(2017, 1, 1, 0, 0), 50245),
#                                  (datetime.datetime(2017, 1, 6, 0, 0), 93623)],
#              '45 ST': [(datetime.datetime(2017, 1, 5, 0, 0), 6986),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 4101),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 4043),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 6932),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 2827),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 7139),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 6683)],
#              '46 ST': [(datetime.datetime(2017, 1, 1, 0, 0), 3158),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 8630),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 8523),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 4153),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 7902),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 4339),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 8690)],
#              '46 ST BLISS ST': [(datetime.datetime(2016, 12, 31, 0, 0), 8817),
#                                 (datetime.datetime(2017, 1, 4, 0, 0), 13397),
#                                 (datetime.datetime(2017, 1, 6, 0, 0), 13197),
#                                 (datetime.datetime(2017, 1, 2, 0, 0), 7704),
#                                 (datetime.datetime(2017, 1, 5, 0, 0), 13208),
#                                 (datetime.datetime(2017, 1, 3, 0, 0), 12743),
#                                 (datetime.datetime(2017, 1, 1, 0, 0), 5558)],
#              '47-50 STS ROCK': [(datetime.datetime(2017, 1, 5, 0, 0), 64809),
#                                 (datetime.datetime(2017, 1, 3, 0, 0), 60691),
#                                 (datetime.datetime(2017, 1, 1, 0, 0), 29604),
#                                 (datetime.datetime(2017, 1, 6, 0, 0), 61289),
#                                 (datetime.datetime(2017, 1, 2, 0, 0), 25148),
#                                 (datetime.datetime(2016, 12, 31, 0, 0), 29167),
#                                 (datetime.datetime(2017, 1, 4, 0, 0), 65644)],
#              '49 ST': [(datetime.datetime(2017, 1, 1, 0, 0), 13698),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 24588),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 2779),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 24684),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 13214),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 24772),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 24961)],
#              '4AV-9 ST': [(datetime.datetime(2017, 1, 5, 0, 0), 9430),
#                           (datetime.datetime(2016, 12, 31, 0, 0), 4592),
#                           (datetime.datetime(2017, 1, 6, 0, 0), 9229),
#                           (datetime.datetime(2017, 1, 2, 0, 0), 4299),
#                           (datetime.datetime(2017, 1, 3, 0, 0), 8600),
#                           (datetime.datetime(2017, 1, 1, 0, 0), 3113),
#                           (datetime.datetime(2017, 1, 4, 0, 0), 9410)],
#              '5 AV/53 ST': [(datetime.datetime(2017, 1, 3, 0, 0), 27045),
#                             (datetime.datetime(2016, 12, 31, 0, 0), 9229),
#                             (datetime.datetime(2017, 1, 2, 0, 0), 7889),
#                             (datetime.datetime(2017, 1, 6, 0, 0), 26203),
#                             (datetime.datetime(2017, 1, 4, 0, 0), 26782),
#                             (datetime.datetime(2017, 1, 1, 0, 0), 6968),
#                             (datetime.datetime(2017, 1, 5, 0, 0), 26774)],
#              '5 AV/59 ST': [(datetime.datetime(2017, 1, 4, 0, 0), 15887),
#                             (datetime.datetime(2017, 1, 6, 0, 0), 15460),
#                             (datetime.datetime(2017, 1, 2, 0, 0), 8072),
#                             (datetime.datetime(2016, 12, 31, 0, 0), 9836),
#                             (datetime.datetime(2017, 1, 5, 0, 0), 15826),
#                             (datetime.datetime(2017, 1, 3, 0, 0), 14824),
#                             (datetime.datetime(2017, 1, 1, 0, 0), 9055)],
#              '5 AVE': [(datetime.datetime(2017, 1, 1, 0, 0), 4792),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 13739),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 13724),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 13239),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 3676),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 12549),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 5231)],
#              '50 ST': [(datetime.datetime(2017, 1, 2, 0, 0), 24657),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 51126),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 49005),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 28087),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 48299),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 50637),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 25616)],
#              '51 ST': [(datetime.datetime(2017, 1, 3, 0, 0), 21179),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 10539),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 21816),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 21710),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 9075),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 8404),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 21114)],
#              '52 ST': [(datetime.datetime(2017, 1, 5, 0, 0), 6134),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 6098),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 5965),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 3502),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 3579),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 6039),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 2631)],
#              '53 ST': [(datetime.datetime(2017, 1, 6, 0, 0), 7025),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 3709),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 7063),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 4203),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 4611),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 7249),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 7323)],
#              '55 ST': [(datetime.datetime(2016, 12, 31, 0, 0), 701),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 2100),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 789),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 2249),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 2356),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 1370),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 2293)],
#              '57 ST': [(datetime.datetime(2017, 1, 2, 0, 0), 6356),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 13966),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 13081),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 8542),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 12756),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 8772),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 13336)],
#              '57 ST-7 AV': [(datetime.datetime(2017, 1, 6, 0, 0), 31157),
#                             (datetime.datetime(2016, 12, 31, 0, 0), 12751),
#                             (datetime.datetime(2017, 1, 4, 0, 0), 31314),
#                             (datetime.datetime(2017, 1, 5, 0, 0), 31170),
#                             (datetime.datetime(2017, 1, 3, 0, 0), 29239),
#                             (datetime.datetime(2017, 1, 1, 0, 0), 13481),
#                             (datetime.datetime(2017, 1, 2, 0, 0), 15664)],
#              '59 ST': [(datetime.datetime(2017, 1, 2, 0, 0), 35286),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 69173),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 74454),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 71375),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 25894),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 73760),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 37040)],
#              '59 ST COLUMBUS': [(datetime.datetime(2016, 12, 31, 0, 0), 49413),
#                                 (datetime.datetime(2017, 1, 5, 0, 0), 66759),
#                                 (datetime.datetime(2017, 1, 2, 0, 0), 34050),
#                                 (datetime.datetime(2017, 1, 4, 0, 0), 67531),
#                                 (datetime.datetime(2017, 1, 6, 0, 0), 64062),
#                                 (datetime.datetime(2017, 1, 3, 0, 0), 61779),
#                                 (datetime.datetime(2017, 1, 1, 0, 0), 29709)],
#              '6 AV': [(datetime.datetime(2017, 1, 6, 0, 0), 5443),
#                       (datetime.datetime(2017, 1, 1, 0, 0), 2356),
#                       (datetime.datetime(2017, 1, 2, 0, 0), 3103),
#                       (datetime.datetime(2017, 1, 3, 0, 0), 4902),
#                       (datetime.datetime(2017, 1, 4, 0, 0), 5161),
#                       (datetime.datetime(2017, 1, 5, 0, 0), 5221),
#                       (datetime.datetime(2016, 12, 31, 0, 0), 3786)],
#              '61 ST WOODSIDE': [(datetime.datetime(2016, 12, 31, 0, 0), 9143),
#                                 (datetime.datetime(2017, 1, 4, 0, 0), 16165),
#                                 (datetime.datetime(2017, 1, 3, 0, 0), 15128),
#                                 (datetime.datetime(2017, 1, 6, 0, 0), 15754),
#                                 (datetime.datetime(2017, 1, 2, 0, 0), 8459),
#                                 (datetime.datetime(2017, 1, 1, 0, 0), 6712),
#                                 (datetime.datetime(2017, 1, 5, 0, 0), 15750)],
#              '63 DR-REGO PARK': [(datetime.datetime(2017, 1, 3, 0, 0), 15614),
#                                  (datetime.datetime(2017, 1, 2, 0, 0), 8761),
#                                  (datetime.datetime(2017, 1, 4, 0, 0), 16866),
#                                  (datetime.datetime(2017, 1, 5, 0, 0), 16695),
#                                  (datetime.datetime(2016, 12, 31, 0, 0), 9006),
#                                  (datetime.datetime(2017, 1, 1, 0, 0), 5502),
#                                  (datetime.datetime(2017, 1, 6, 0, 0), 16237)],
#              '65 ST': [(datetime.datetime(2016, 12, 31, 0, 0), 1958),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 1988),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 3502),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 3484),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 1331),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 3497),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 3306)],
#              '66 ST-LINCOLN': [(datetime.datetime(2017, 1, 3, 0, 0), 20748),
#                                (datetime.datetime(2017, 1, 1, 0, 0), 8809),
#                                (datetime.datetime(2016, 12, 31, 0, 0), 10098),
#                                (datetime.datetime(2017, 1, 5, 0, 0), 20926),
#                                (datetime.datetime(2017, 1, 6, 0, 0), 19773),
#                                (datetime.datetime(2017, 1, 4, 0, 0), 20398),
#                                (datetime.datetime(2017, 1, 2, 0, 0), 10253)],
#              '67 AV': [(datetime.datetime(2017, 1, 3, 0, 0), 9434),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 9369),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 9940),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 3828),
#                        (datetime.datetime(2017, 1, 1, 0, 0), 2467),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 9802),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 3819)],
#              '68ST-HUNTER CO': [(datetime.datetime(2017, 1, 2, 0, 0), 7207),
#                                 (datetime.datetime(2017, 1, 3, 0, 0), 21679),
#                                 (datetime.datetime(2017, 1, 6, 0, 0), 21707),
#                                 (datetime.datetime(2017, 1, 5, 0, 0), 22094),
#                                 (datetime.datetime(2016, 12, 31, 0, 0), 8569),
#                                 (datetime.datetime(2017, 1, 4, 0, 0), 21676),
#                                 (datetime.datetime(2017, 1, 1, 0, 0), 6996)],
#              '69 ST': [(datetime.datetime(2017, 1, 1, 0, 0), 2339),
#                        (datetime.datetime(2017, 1, 2, 0, 0), 2964),
#                        (datetime.datetime(2016, 12, 31, 0, 0), 3200),
#                        (datetime.datetime(2017, 1, 5, 0, 0), 4511),
#                        (datetime.datetime(2017, 1, 4, 0, 0), 4704),
#                        (datetime.datetime(2017, 1, 6, 0, 0), 4425),
#                        (datetime.datetime(2017, 1, 3, 0, 0), 4651)],
# ...
#                              (datetime.datetime(2017, 1, 4, 0, 0), 5689)],
#              'SUTPHIN BLVD': [(datetime.datetime(2016, 12, 31, 0, 0), 2250),
#                               (datetime.datetime(2017, 1, 6, 0, 0), 4325),
#                               (datetime.datetime(2017, 1, 3, 0, 0), 4228),
#                               (datetime.datetime(2017, 1, 5, 0, 0), 4424),
#                               (datetime.datetime(2017, 1, 4, 0, 0), 4469),
#                               (datetime.datetime(2017, 1, 1, 0, 0), 1603),
#                               (datetime.datetime(2017, 1, 2, 0, 0), 2149)],
#              'SUTPHIN-ARCHER': [(datetime.datetime(2017, 1, 1, 0, 0), 10619),
#                                 (datetime.datetime(2017, 1, 3, 0, 0), 22642),
#                                 (datetime.datetime(2017, 1, 6, 0, 0), 23358),
#                                 (datetime.datetime(2016, 12, 31, 0, 0), 14455),
#                                 (datetime.datetime(2017, 1, 4, 0, 0), 23849),
#                                 (datetime.datetime(2017, 1, 5, 0, 0), 23569),
#                                 (datetime.datetime(2017, 1, 2, 0, 0), 13691)],
#              'SUTTER AV': [(datetime.datetime(2017, 1, 2, 0, 0), 2300),
#                            (datetime.datetime(2017, 1, 5, 0, 0), 4554),
#                            (datetime.datetime(2017, 1, 3, 0, 0), 4312),
#                            (datetime.datetime(2017, 1, 6, 0, 0), 4700),
#                            (datetime.datetime(2017, 1, 4, 0, 0), 4575),
#                            (datetime.datetime(2016, 12, 31, 0, 0), 2372),
#                            (datetime.datetime(2017, 1, 1, 0, 0), 1755)],
#              'THIRTY ST': [(datetime.datetime(2017, 1, 2, 0, 0), 1491),
#                            (datetime.datetime(2017, 1, 3, 0, 0), 7506),
#                            (datetime.datetime(2017, 1, 4, 0, 0), 8194),
#                            (datetime.datetime(2017, 1, 5, 0, 0), 7405),
#                            (datetime.datetime(2017, 1, 6, 0, 0), 7710),
#                            (datetime.datetime(2016, 12, 31, 0, 0), 1863),
#                            (datetime.datetime(2017, 1, 1, 0, 0), 2885)],
#              'THIRTY THIRD ST': [(datetime.datetime(2017, 1, 2, 0, 0), 7412),
#                                  (datetime.datetime(2017, 1, 1, 0, 0), 9684),
#                                  (datetime.datetime(2017, 1, 6, 0, 0), 18851),
#                                  (datetime.datetime(2017, 1, 5, 0, 0), 20121),
#                                  (datetime.datetime(2017, 1, 3, 0, 0), 1984505),
#                                  (datetime.datetime(2016, 12, 31, 0, 0), 8726),
#                                  (datetime.datetime(2017, 1, 4, 0, 0), 21536)],
#              'TIMES SQ-42 ST': [(datetime.datetime(2017, 1, 2, 0, 0), 45233),
#                                 (datetime.datetime(2017, 1, 4, 0, 0), 98051),
#                                 (datetime.datetime(2017, 1, 6, 0, 0), 91831),
#                                 (datetime.datetime(2017, 1, 3, 0, 0), 89262),
#                                 (datetime.datetime(2016, 12, 31, 0, 0), 17277),
#                                 (datetime.datetime(2017, 1, 5, 0, 0), 94471),
#                                 (datetime.datetime(2017, 1, 1, 0, 0), 49504)],
#              'TOMPKINSVILLE': [(datetime.datetime(2017, 1, 2, 0, 0), 322),
#                                (datetime.datetime(2017, 1, 3, 0, 0), 675),
#                                (datetime.datetime(2017, 1, 5, 0, 0), 788),
#                                (datetime.datetime(2017, 1, 1, 0, 0), 214),
#                                (datetime.datetime(2016, 12, 31, 0, 0), 364),
#                                (datetime.datetime(2017, 1, 6, 0, 0), 693),
#                                (datetime.datetime(2017, 1, 4, 0, 0), 749)],
#              'TREMONT AV': [(datetime.datetime(2017, 1, 1, 0, 0), 3708),
#                             (datetime.datetime(2017, 1, 3, 0, 0), 9155),
#                             (datetime.datetime(2017, 1, 2, 0, 0), 5052),
#                             (datetime.datetime(2017, 1, 6, 0, 0), 9792),
#                             (datetime.datetime(2017, 1, 4, 0, 0), 9758),
#                             (datetime.datetime(2016, 12, 31, 0, 0), 5153),
#                             (datetime.datetime(2017, 1, 5, 0, 0), 9846)],
#              'TWENTY THIRD ST': [(datetime.datetime(2017, 1, 5, 0, 0), 8844),
#                                  (datetime.datetime(2017, 1, 4, 0, 0), 9076),
#                                  (datetime.datetime(2017, 1, 6, 0, 0), 8078),
#                                  (datetime.datetime(2017, 1, 1, 0, 0), 2088),
#                                  (datetime.datetime(2016, 12, 31, 0, 0), 2104),
#                                  (datetime.datetime(2017, 1, 2, 0, 0), 2197),
#                                  (datetime.datetime(2017, 1, 3, 0, 0), 8859)],
#              'UNION ST': [(datetime.datetime(2017, 1, 2, 0, 0), 3072),
#                           (datetime.datetime(2017, 1, 3, 0, 0), 6272),
#                           (datetime.datetime(2017, 1, 1, 0, 0), 2059),
#                           (datetime.datetime(2017, 1, 4, 0, 0), 6342),
#                           (datetime.datetime(2016, 12, 31, 0, 0), 3066),
#                           (datetime.datetime(2017, 1, 5, 0, 0), 6521),
#                           (datetime.datetime(2017, 1, 6, 0, 0), 6511)],
#              'UTICA AV': [(datetime.datetime(2017, 1, 3, 0, 0), 14775),
#                           (datetime.datetime(2017, 1, 4, 0, 0), 15276),
#                           (datetime.datetime(2017, 1, 1, 0, 0), 6905),
#                           (datetime.datetime(2017, 1, 2, 0, 0), 8136),
#                           (datetime.datetime(2017, 1, 6, 0, 0), 15218),
#                           (datetime.datetime(2016, 12, 31, 0, 0), 8838),
#                           (datetime.datetime(2017, 1, 5, 0, 0), 15352)],
#              'V.CORTLANDT PK': [(datetime.datetime(2017, 1, 1, 0, 0), 2426),
#                                 (datetime.datetime(2017, 1, 4, 0, 0), 7161),
#                                 (datetime.datetime(2017, 1, 3, 0, 0), 6570),
#                                 (datetime.datetime(2017, 1, 5, 0, 0), 6912),
#                                 (datetime.datetime(2016, 12, 31, 0, 0), 3487),
#                                 (datetime.datetime(2017, 1, 2, 0, 0), 3387),
#                                 (datetime.datetime(2017, 1, 6, 0, 0), 6841)],
#              'VAN SICLEN AV': [(datetime.datetime(2017, 1, 3, 0, 0), 8420),
#                                (datetime.datetime(2017, 1, 5, 0, 0), 9080),
#                                (datetime.datetime(2017, 1, 4, 0, 0), 9174),
#                                (datetime.datetime(2016, 12, 31, 0, 0), 4628),
#                                (datetime.datetime(2017, 1, 6, 0, 0), 9063),
#                                (datetime.datetime(2017, 1, 2, 0, 0), 4470),
#                                (datetime.datetime(2017, 1, 1, 0, 0), 3217)],
#              'VAN SICLEN AVE': [(datetime.datetime(2017, 1, 2, 0, 0), 1706),
#                                 (datetime.datetime(2017, 1, 5, 0, 0), 3208),
#                                 (datetime.datetime(2017, 1, 3, 0, 0), 3057),
#                                 (datetime.datetime(2017, 1, 4, 0, 0), 3203),
#                                 (datetime.datetime(2016, 12, 31, 0, 0), 1689),
#                                 (datetime.datetime(2017, 1, 6, 0, 0), 3291),
#                                 (datetime.datetime(2017, 1, 1, 0, 0), 1362)],
#              'VERNON-JACKSON': [(datetime.datetime(2017, 1, 2, 0, 0), 6529),
#                                 (datetime.datetime(2017, 1, 3, 0, 0), 14152),
#                                 (datetime.datetime(2017, 1, 1, 0, 0), 5549),
#                                 (datetime.datetime(2016, 12, 31, 0, 0), 7566),
#                                 (datetime.datetime(2017, 1, 5, 0, 0), 15671),
#                                 (datetime.datetime(2017, 1, 4, 0, 0), 15554),
#                                 (datetime.datetime(2017, 1, 6, 0, 0), 15276)],
#              'W 4 ST-WASH SQ': [(datetime.datetime(2017, 1, 5, 0, 0), 30708),
#                                 (datetime.datetime(2017, 1, 4, 0, 0), 30770),
#                                 (datetime.datetime(2017, 1, 2, 0, 0), 16362),
#                                 (datetime.datetime(2017, 1, 3, 0, 0), 27210),
#                                 (datetime.datetime(2017, 1, 1, 0, 0), 18130),
#                                 (datetime.datetime(2017, 1, 6, 0, 0), 30199),
#                                 (datetime.datetime(2016, 12, 31, 0, 0), 18851)],
#              'W 8 ST-AQUARIUM': [(datetime.datetime(2017, 1, 6, 0, 0), 1959),
#                                  (datetime.datetime(2016, 12, 31, 0, 0), 801),
#                                  (datetime.datetime(2017, 1, 3, 0, 0), 1956),
#                                  (datetime.datetime(2017, 1, 5, 0, 0), 1954),
#                                  (datetime.datetime(2017, 1, 1, 0, 0), 1080),
#                                  (datetime.datetime(2017, 1, 2, 0, 0), 931),
#                                  (datetime.datetime(2017, 1, 4, 0, 0), 2128)],
#              'WAKEFIELD/241': [(datetime.datetime(2017, 1, 2, 0, 0), 2585),
#                                (datetime.datetime(2017, 1, 3, 0, 0), 4606),
#                                (datetime.datetime(2016, 12, 31, 0, 0), 2957),
#                                (datetime.datetime(2017, 1, 5, 0, 0), 4969),
#                                (datetime.datetime(2017, 1, 4, 0, 0), 5011),
#                                (datetime.datetime(2017, 1, 1, 0, 0), 2139),
#                                (datetime.datetime(2017, 1, 6, 0, 0), 4911)],
#              'WALL ST': [(datetime.datetime(2017, 1, 2, 0, 0), 10457),
#                          (datetime.datetime(2016, 12, 31, 0, 0), 10839),
#                          (datetime.datetime(2017, 1, 1, 0, 0), 8657),
#                          (datetime.datetime(2017, 1, 3, 0, 0), 44845),
#                          (datetime.datetime(2017, 1, 5, 0, 0), 47923),
#                          (datetime.datetime(2017, 1, 6, 0, 0), 44100),
#                          (datetime.datetime(2017, 1, 4, 0, 0), 47689)],
#              'WEST FARMS SQ': [(datetime.datetime(2017, 1, 6, 0, 0), 7229),
#                                (datetime.datetime(2016, 12, 31, 0, 0), 3909),
#                                (datetime.datetime(2017, 1, 3, 0, 0), 6655),
#                                (datetime.datetime(2017, 1, 2, 0, 0), 3767),
#                                (datetime.datetime(2017, 1, 5, 0, 0), 7380),
#                                (datetime.datetime(2017, 1, 4, 0, 0), 7730),
#                                (datetime.datetime(2017, 1, 1, 0, 0), 2921)],
#              'WESTCHESTER SQ': [(datetime.datetime(2017, 1, 3, 0, 0), 6374),
#                                 (datetime.datetime(2017, 1, 2, 0, 0), 2323),
#                                 (datetime.datetime(2017, 1, 5, 0, 0), 6663),
#                                 (datetime.datetime(2017, 1, 1, 0, 0), 1581),
#                                 (datetime.datetime(2017, 1, 4, 0, 0), 6711),
#                                 (datetime.datetime(2016, 12, 31, 0, 0), 2414),
#                                 (datetime.datetime(2017, 1, 6, 0, 0), 6526)],
#              'WHITEHALL S-FRY': [(datetime.datetime(2017, 1, 1, 0, 0), 6328),
#                                  (datetime.datetime(2017, 1, 2, 0, 0), 6036),
#                                  (datetime.datetime(2016, 12, 31, 0, 0), 6808),
#                                  (datetime.datetime(2017, 1, 3, 0, 0), 15050),
#                                  (datetime.datetime(2017, 1, 6, 0, 0), 14792),
#                                  (datetime.datetime(2017, 1, 4, 0, 0), 16890),
#                                  (datetime.datetime(2017, 1, 5, 0, 0), 16573)],
#              'WHITLOCK AV': [(datetime.datetime(2017, 1, 5, 0, 0), 1917),
#                              (datetime.datetime(2017, 1, 3, 0, 0), 1802),
#                              (datetime.datetime(2017, 1, 1, 0, 0), 699),
#                              (datetime.datetime(2017, 1, 6, 0, 0), 1871),
#                              (datetime.datetime(2017, 1, 4, 0, 0), 1908),
#                              (datetime.datetime(2016, 12, 31, 0, 0), 1043),
#                              (datetime.datetime(2017, 1, 2, 0, 0), 980)],
#              'WILSON AV': [(datetime.datetime(2017, 1, 5, 0, 0), 4334),
#                            (datetime.datetime(2017, 1, 1, 0, 0), 2169),
#                            (datetime.datetime(2017, 1, 2, 0, 0), 2728),
#                            (datetime.datetime(2017, 1, 4, 0, 0), 4454),
#                            (datetime.datetime(2016, 12, 31, 0, 0), 3279),
#                            (datetime.datetime(2017, 1, 6, 0, 0), 4455),
#                            (datetime.datetime(2017, 1, 3, 0, 0), 4140)],
#              'WINTHROP ST': [(datetime.datetime(2017, 1, 6, 0, 0), 6905),
#                              (datetime.datetime(2016, 12, 31, 0, 0), 2541),
#                              (datetime.datetime(2017, 1, 2, 0, 0), 2666),
#                              (datetime.datetime(2017, 1, 1, 0, 0), 1852),
#                              (datetime.datetime(2017, 1, 5, 0, 0), 7018),
#                              (datetime.datetime(2017, 1, 3, 0, 0), 6580),
#                              (datetime.datetime(2017, 1, 4, 0, 0), 6932)],
#              'WOODHAVEN BLVD': [(datetime.datetime(2017, 1, 2, 0, 0), 14875),
#                                 (datetime.datetime(2016, 12, 31, 0, 0), 16304),
#                                 (datetime.datetime(2017, 1, 3, 0, 0), 24362),
#                                 (datetime.datetime(2017, 1, 5, 0, 0), 25204),
#                                 (datetime.datetime(2017, 1, 1, 0, 0), 10055),
#                                 (datetime.datetime(2017, 1, 4, 0, 0), 25461),
#                                 (datetime.datetime(2017, 1, 6, 0, 0), 25289)],
#              'WOODLAWN': [(datetime.datetime(2017, 1, 4, 0, 0), 7120),
#                           (datetime.datetime(2016, 12, 31, 0, 0), 3990),
#                           (datetime.datetime(2017, 1, 6, 0, 0), 7068),
#                           (datetime.datetime(2017, 1, 1, 0, 0), 2534),
#                           (datetime.datetime(2017, 1, 3, 0, 0), 6642),
#                           (datetime.datetime(2017, 1, 5, 0, 0), 7036),
#                           (datetime.datetime(2017, 1, 2, 0, 0), 3501)],
#              'WORLD TRADE CTR': [(datetime.datetime(2017, 1, 3, 0, 0), 14326),
#                                  (datetime.datetime(2017, 1, 2, 0, 0), 6485),
#                                  (datetime.datetime(2017, 1, 4, 0, 0), 15798),
#                                  (datetime.datetime(2017, 1, 6, 0, 0), 14226),
#                                  (datetime.datetime(2016, 12, 31, 0, 0), 8376),
#                                  (datetime.datetime(2017, 1, 5, 0, 0), 14900),
#                                  (datetime.datetime(2017, 1, 1, 0, 0), 7923)],
#              'YORK ST': [(datetime.datetime(2017, 1, 6, 0, 0), 9025),
#                          (datetime.datetime(2017, 1, 3, 0, 0), 8342),
#                          (datetime.datetime(2017, 1, 5, 0, 0), 9264),
#                          (datetime.datetime(2017, 1, 1, 0, 0), 5456),
#                          (datetime.datetime(2017, 1, 2, 0, 0), 4142),
#                          (datetime.datetime(2017, 1, 4, 0, 0), 9822),
#                          (datetime.datetime(2016, 12, 31, 0, 0), 4361)],
#              'ZEREGA AV': [(datetime.datetime(2017, 1, 4, 0, 0), 2692),
#                            (datetime.datetime(2016, 12, 31, 0, 0), 1067),
#                            (datetime.datetime(2017, 1, 3, 0, 0), 2485),
#                            (datetime.datetime(2017, 1, 6, 0, 0), 2556),
#                            (datetime.datetime(2017, 1, 2, 0, 0), 1028),
#                            (datetime.datetime(2017, 1, 5, 0, 0), 2689),
#                            (datetime.datetime(2017, 1, 1, 0, 0), 791)]})

# %% [markdown]
# ## Exercise 7
# - Plot the time series for a station

# %%
# create date count dictionary for one station from the 12/31/16 data
dates = []
counts = []
firstpair = {k: dict5[k] for k in list(dict5.keys())[:1]} #choose one station with key/value
firstweek_key = firstpair.keys()
for tup in firstpair.values():
    for date, count in tup:
        dates.append(date)
        counts.append(count)

plt.figure(figsize=(10,3))
plt.plot(dates, counts, 'ro')
plt.title('Time series for station {}'.format(firstpair.keys()))
plt.xlabel('Date')
plt.ylabel('Entries per day')

# %%
firstpair =
# Out:
# {'9TH STREET': [(datetime.datetime(2016, 12, 26, 0, 0), 1170),
#   (datetime.datetime(2016, 12, 24, 0, 0), 1215),
#   (datetime.datetime(2016, 12, 30, 0, 0), 2857),
#   (datetime.datetime(2016, 12, 29, 0, 0), 2579),
#   (datetime.datetime(2016, 12, 25, 0, 0), 1071),
#   (datetime.datetime(2016, 12, 27, 0, 0), 2576),
#   (datetime.datetime(2016, 12, 28, 0, 0), 3005)]}

# %%
# create date count dictionary for one station from the 12/31/16 data
dates2 = []
counts2 = []

firstpair2 = {k: dict5_file2[k] for k in dict5_file2 if k == '9TH STREET'} #choose one station with key/value
for tup in firstpair2.values():
    for date, count in tup:
        dates2.append(date)
        counts2.append(count)

plt.figure(figsize=(10,3))
plt.plot(dates2, counts2, 'ro')
plt.title('Time series for station {}'.format(firstpair2.keys()))
plt.xlabel('Date')
plt.ylabel('Entries per day')

# %% [markdown]
# ## Exercise 8
# - Make one list of counts for **one** week for one station. Monday's count, Tuesday's count, etc. so it's a list of 7 counts.
# Make the same list for another week, and another week, and another week.
# `plt.plot(week_count_list)` for every `week_count_list` you created this way. You should get a rainbow plot of weekly commute numbers on top of each other.

# %%
weekcount_lst = []

# need key:value pairs for one station in 1 week, then apply to multiple weeks
firstweek = {k: dict5[k] for k in list(dict5.keys())[:1]}
firstweek_key = firstweek.keys()

# obtain 2nd week key:value pair based on key of the first week
secondweek = {firstweek_key: dict5_file2[firstweek_key] for firstweek_key in dict5_file2.keys()}

# iterate through each day in each week and append the daily ridership
for pairs in firstweek, secondweek:
    temp_dict = defaultdict(list)
    for datecount_pair in pairs.values():
        for date,count in datecount_pair:
            temp_dict[date] = count
    for key in sorted(temp_dict):
        weekcount_lst.append(temp_dict[key])
        
# multiple weeks split
weekcount_lst1 = weekcount_lst[:7]
weekcount_lst2 = weekcount_lst[7:14]

plt.figure(figsize=(10,5))
plt.plot(weekcount_lst2 , 'ro', label='12/31/16')
plt.plot(weekcount_lst1, 'bo', label='1/7/17')
plt.title('Station {} weekly entries'.format(firstweek.keys()))
plt.xlabel('Day')
plt.ylabel('Daily Entries')
plt.legend(loc=2, prop={'size':8})

x = [0,1,2,3,4,5,6]
days = ['Sat','Sun','Mon','Tue','Wed','Thu','Fri']
plt.xticks(x, days, rotation=45)
# Out:
# ([<matplotlib.axis.XTick at 0x122876d30>,
#   <matplotlib.axis.XTick at 0x1239abbe0>,
#   <matplotlib.axis.XTick at 0x123982588>,
#   <matplotlib.axis.XTick at 0x122bf81d0>,
#   <matplotlib.axis.XTick at 0x122bf8ba8>,
#   <matplotlib.axis.XTick at 0x122c015f8>,
#   <matplotlib.axis.XTick at 0x122c11048>],
#  <a list of 7 Text xticklabel objects>)

# %%
pprint(weekcount_lst)
# Out:
# [5344,
#  3873,
#  5268,
#  11808,
#  12887,
#  12480,
#  12450,
#  5237,
#  3239,
#  5673,
#  9769,
#  10046,
#  9546,
#  9874]

# %% [markdown]
# ## Exercise 9
# - Over multiple weeks, sum total ridership for each station and sort them, so you can find out the stations with the highest traffic during the time you investigate

# %%
dict5['GRD CNTRL-42 ST']
# Out:
# [(datetime.datetime(2016, 12, 30, 0, 0), 112058),
#  (datetime.datetime(2016, 12, 28, 0, 0), 125408),
#  (datetime.datetime(2016, 12, 29, 0, 0), 117689),
#  (datetime.datetime(2016, 12, 24, 0, 0), 37659),
#  (datetime.datetime(2016, 12, 27, 0, 0), 113222),
#  (datetime.datetime(2016, 12, 26, 0, 0), 54999),
#  (datetime.datetime(2016, 12, 25, 0, 0), 29869)]

# %%
dict5_file2['GRD CNTRL-42 ST']
# Out:
# [(datetime.datetime(2017, 1, 4, 0, 0), 149522),
#  (datetime.datetime(2017, 1, 1, 0, 0), 38217),
#  (datetime.datetime(2017, 1, 2, 0, 0), 47430),
#  (datetime.datetime(2016, 12, 31, 0, 0), 55247),
#  (datetime.datetime(2017, 1, 5, 0, 0), 152447),
#  (datetime.datetime(2017, 1, 3, 0, 0), 150486),
#  (datetime.datetime(2017, 1, 6, 0, 0), 145197)]

# %%
# create combined dictionary
large_dict = defaultdict(list)
both_dict = [dict5, dict5_file2]

# large dictionary with date and entry for all weeks
# iterate through each dictionary and append total rides
for d in both_dict:
    for k,v in d.items():
        for pair in v:
            large_dict[k].append(pair)


large_dict2 = defaultdict(list)

# iterate through the new dictionary and create station, entries by day
for k,v in large_dict.items():
    for pair in v:
        large_dict2[k].append(pair[1])
        
# summing entries for the week in the latest dictionary
for k,v in large_dict2.items():
    large_dict2[k] = sum(v)

# sorting by total number of entries
sorted_pairs = (sorted(large_dict2.items(), key=lambda x: x[1], reverse=True))

pprint(sorted_pairs)
# Out:
# [('5 AVE', 986116510),
#  ('OCEAN PKWY', 111573591),
#  ('CANAL ST', 97639056),
#  ('34 ST-PENN STA', 68221301),
#  ('96 ST', 67729722),
#  ('225 ST', 12069780),
#  ('FLUSHING-MAIN', 4570780),
#  ('THIRTY THIRD ST', 2164457),
#  ('GRD CNTRL-42 ST', 1329450),
#  ('34 ST-HERALD SQ', 1325021),
#  ('42 ST-PORT AUTH', 1059180),
#  ('TIMES SQ-42 ST', 989294),
#  ('23 ST', 978841),
#  ('86 ST', 975637),
#  ('JOURNAL SQUARE', 905988),
#  ('FULTON ST', 858919),
#  ('14 ST-UNION SQ', 844026),
#  ('125 ST', 768914),
#  ('59 ST', 746881),
#  ('47-50 STS ROCK', 699581),
#  ('59 ST COLUMBUS', 677741),
#  ('SOUTH FERRY', 560108),
#  ('14 ST', 547035),
#  ('50 ST', 531545),
#  ('JKSN HT-ROOSVLT', 525680),
#  ('PAVONIA/NEWPORT', 517766),
#  ('CHAMBERS ST', 511973),
#  ('72 ST', 447972),
#  ('ATL AV-BARCLAY', 431442),
#  ('42 ST-BRYANT PK', 406728),
#  ('28 ST', 404190),
#  ('JAMAICA CENTER', 386659),
#  ('LEXINGTON AV/53', 382555),
#  ('145 ST', 375727),
#  ('8 AV', 367289),
#  ('WALL ST', 364803),
#  ('CHURCH AV', 363181),
#  ('JAY ST-METROTEC', 361233),
#  ('GRAND ST', 345831),
#  ('77 ST', 341540),
#  ('116 ST', 336923),
#  ('7 AV', 329858),
#  ('CROWN HTS-UTICA', 313477),
#  ('103 ST', 308875),
#  ('W 4 ST-WASH SQ', 308546),
#  ('BOROUGH HALL', 304990),
#  ('57 ST-7 AV', 298756),
#  ('DEKALB AV', 292557),
#  ('49 ST', 285962),
#  ('WOODHAVEN BLVD', 285184),
#  ('BOWLING GREEN', 279092),
#  ('BEDFORD AV', 262657),
#  ('SUTPHIN-ARCHER', 262162),
#  ('FOREST HILLS 71', 256431),
#  ('KINGS HWY', 255188),
#  ('161/YANKEE STAD', 252411),
#  ('33 ST', 250362),
#  ('5 AV/53 ST', 246416),
#  ('FORDHAM RD', 246074),
#  ('3 AV-149 ST', 243581),
#  ('KEW GARDENS', 243025),
#  ('SPRING ST', 239398),
#  ('168 ST', 231749),
#  ('181 ST', 231231),
#  ('79 ST', 226633),
#  ('DELANCEY/ESSEX', 226400),
#  ('103 ST-CORONA', 220836),
#  ('51 ST', 220387),
#  ('NOSTRAND AV', 220123),
#  ('JAMAICA 179 ST', 212288),
#  ('BAY PKWY', 211593),
#  ('JUNCTION BLVD', 210895),
#  ('68ST-HUNTER CO', 210663),
#  ('167 ST', 207521),
#  ('1 AV', 206521),
#  ('MYRTLE-WYCKOFF', 204868),
#  ('GRAND-NEWTOWN', 202127),
#  ('135 ST', 201014),
#  ('CORTLANDT ST', 200628),
#  ('66 ST-LINCOLN', 199799),
#  ("B'WAY-LAFAYETTE", 196282),
#  ('FRANKLIN AV', 186393),
#  ('81 ST-MUSEUM', 185770),
#  ('CATHEDRAL PKWY', 183844),
#  ('90 ST-ELMHURST', 183306),
#  ('5 AV/59 ST', 182945),
#  ('PRINCE ST', 179811),
#  ('FLATBUSH AV-B.C', 178591),
#  ('2 AV', 177565),
#  ('GROVE STREET', 174831),
#  ('BROOKLYN BRIDGE', 174614),
#  ('111 ST', 174058),
#  ('63 DR-REGO PARK', 173988),
#  ('82 ST-JACKSON H', 171270),
#  ('170 ST', 168710),
#  ('KINGSBRIDGE RD', 167071),
#  ('ASTORIA DITMARS', 164800),
#  ('WORLD TRADE CTR', 164431),
#  ('36 ST', 164177),
#  ('61 ST WOODSIDE', 164164),
#  ('BROADWAY', 163112),
#  ('EAST BROADWAY', 160619),
#  ('LEXINGTON AV/63', 159594),
#  ('85 ST-FOREST PK', 158494),
#  ('WHITEHALL S-FRY', 157749),
#  ('PARKCHESTER', 157237),
#  ('RECTOR ST', 155499),
#  ('UTICA AV', 153955),
#  ('BLEECKER ST', 152820),
#  ('8 ST-NYU', 152508),
#  ('STEINWAY ST', 147185),
#  ('HALSEY ST', 147024),
#  ('ELMHURST AV', 146705),
#  ('46 ST BLISS ST', 143581),
#  ('EXCHANGE PLACE', 142441),
#  ('VERNON-JACKSON', 142385),
#  ('DYCKMAN ST', 142226),
#  ('57 ST', 139787),
#  ('30 AV', 138749),
#  ('NEWARK BM BW', 137044),
#  ('BERGEN ST', 133571),
#  ('175 ST', 133064),
#  ('18 AV', 132860),
#  ('CHRISTOPHER ST', 130226),
#  ('CITY / BUS', 129938),
#  ('SHEEPSHEAD BAY', 128915),
#  ('PROSPECT AV', 128235),
#  ('ASTOR PL', 127199),
#  ('CONEY IS-STILLW', 125797),
#  ('MARCY AV', 124695),
#  ('110 ST', 124635),
#  ('137 ST CITY COL', 122680),
#  ('GUN HILL RD', 122670),
#  ('ST. GEORGE', 121548),
#  ('149/GRAND CONC', 119392),
#  ('METROPOLITAN AV', 118930),
#  ('ROCKAWAY AV', 118577),
#  ('QUEENSBORO PLZ', 118007),
#  ('CLINTON-WASH AV', 117692),
#  ('BEDFORD PK BLVD', 117535),
#  ('CANARSIE-ROCKAW', 117494),
#  ('BRIGHTON BEACH', 116644),
#  ('PELHAM PKWY', 115589),
#  ('45 ST', 114147),
#  ('ASTORIA BLVD', 114085),
#  ('AVENUE U', 112862),
#  ('MYRTLE AV', 111081),
#  ('BURNSIDE AV', 110675),
#  ('FLUSHING AV', 110172),
#  ('EUCLID AV', 109876),
#  ('COURT SQ', 109673),
#  ('157 ST', 109175),
#  ('40 ST LOWERY ST', 105311),
#  ('HOUSTON ST', 102819),
#  ('231 ST', 101823),
#  ('TREMONT AV', 100841),
#  ('JFK JAMAICA CT1', 100115),
#  ('CARROLL ST', 99558),
#  ('72 ST-2 AVE', 98295),
#  ('HOYT-SCHER', 98212),
#  ('LORIMER ST', 98190),
#  ('NEWKIRK PLAZA', 97613),
#  ('HUNTS POINT AV', 97533),
#  ('PROSPECT PARK', 97323),
#  ('21 ST-QNSBRIDGE', 97160),
#  ('CENTRAL PK N110', 96607),
#  ('GRAHAM AV', 95442),
#  ('86 ST-2 AVE', 95422),
#  ('NEVINS ST', 95397),
#  ('SIMPSON ST', 94706),
#  ('BROADWAY JCT', 94691),
#  ('FT HAMILTON PKY', 94010),
#  ('HIGH ST', 90713),
#  ('191 ST', 89994),
#  ('VAN SICLEN AV', 89945),
#  ('QUEENS PLAZA', 89555),
#  ('YORK ST', 88167),
#  ('67 AV', 87671),
#  ('169 ST', 87658),
#  ('NORWOOD 205 ST', 87276),
#  ('GREENPOINT AV', 86022),
#  ('INWOOD-207 ST', 84925),
#  ('4AV-9 ST', 84709),
#  ('46 ST', 83900),
#  ('MOSHOLU PKWY', 82757),
#  ('BEDFORD-NOSTRAN', 82711),
#  ('BAY RIDGE AV', 82067),
#  ('33 ST-RAWSON ST', 81586),
#  ('NASSAU ST', 81442),
#  ('HARRISON', 79841),
#  ('116 ST-COLUMBIA', 79835),
#  ('53 ST', 77802),
#  ('34 ST-HUDSON YD', 77259),
#  ('HOYT ST', 77101),
#  ('MORGAN AV', 76924),
#  ('3 AV 138 ST', 75711),
#  ('WEST FARMS SQ', 74234),
#  ('THIRTY ST', 73823),
#  ('174 ST', 73794),
#  ('COURT SQ-23 ST', 73536),
#  ('E 180 ST', 72358),
#  ('18 ST', 72267),
#  ('MORISN AV/SNDVW', 72083),
#  ('WOODLAWN', 71586),
#  ('ROCKAWAY BLVD', 71438),
#  ('NEWKIRK AV', 71149),
#  ('PELHAM BAY PARK', 70694),
#  ('71 ST', 70362),
#  ('MONTROSE AV', 70352),
#  ('NORTHERN BLVD', 70155),
#  ('207 ST', 70032),
#  ('14TH STREET', 69858),
#  ('36 AV', 69623),
#  ('CASTLE HILL AV', 69529),
#  ('V.CORTLANDT PK', 69483),
#  ('ROOSEVELT ISLND', 69156),
#  ('GRAND ARMY PLAZ', 68534),
#  ('155 ST', 68313),
#  ('183 ST', 67570),
#  ('TWENTY THIRD ST', 67325),
#  ('ELDER AV', 66665),
#  ('JEFFERSON ST', 66367),
#  ('GRANT AV', 66305),
#  ('176 ST', 65960),
#  ('PARSONS BLVD', 65730),
#  ('3 AV', 65692),
#  ('25 AV', 65668),
#  ('KINGSTON-THROOP', 65448),
#  ('20 AV', 65242),
#  ('96 ST-2 AVE', 65152),
#  ('52 ST', 64780),
#  ('NEW LOTS AV', 63749),
#  ('GATES AV', 63691),
#  ('CORTELYOU RD', 63656),
#  ('AVENUE J', 63554),
#  ('OZONE PK LEFFRT', 62903),
#  ('LACKAWANNA', 62716),
#  ('WINTHROP ST', 62238),
#  ('BROOK AV', 61468),
#  ('MARBLE HILL-225', 61006),
#  ('9 AV', 59707),
#  ('BROAD ST', 59534),
#  ('WESTCHESTER SQ', 59461),
#  ('CITY HALL', 58462),
#  ('STERLING ST', 58248),
#  ('JACKSON AV', 58109),
#  ('AVENUE M', 58016),
#  ('BAY RIDGE-95 ST', 57998),
#  ('174-175 STS', 57626),
#  ('RALPH AV', 57621),
#  ('SARATOGA AV', 57616),
#  ('UNION ST', 57575),
#  ('MT EDEN AV', 57547),
#  ('PARKSIDE AV', 57264),
#  ('FRESH POND RD', 55630),
#  ('15 ST-PROSPECT', 55291),
#  ('MYRTLE-WILLOUGH', 54976),
#  ('182-183 STS', 54895),
#  ('HUNTERS PT AV', 54738),
#  ('6 AV', 54249),
#  ('KINGSTON AV', 54146),
#  ('ALLERTON AV', 53974),
#  ('CLARK ST', 52986),
#  ('FAR ROCKAWAY', 52624),
#  ('69 ST', 52177),
#  ('NEW LOTS', 52097),
#  ('NEW UTRECHT AV', 52010),
#  ('WAKEFIELD/241', 51401),
#  ('233 ST', 50489),
#  ('BRIARWOOD', 50461),
#  ('FREEMAN ST', 49635),
#  ('KOSCIUSZKO ST', 49602),
#  ('CRESCENT ST', 49362),
#  ('CLASSON AV', 47450),
#  ('PARK PLACE', 47416),
#  ('E 149 ST', 47333),
#  ('JAMAICA VAN WK', 46979),
#  ('NEWARK HW BMEBE', 46802),
#  ('NECK RD', 45817),
#  ('WILSON AV', 45702),
#  ('SMITH-9 ST', 45647),
#  ('SUTTER AV', 45555),
#  ('RIT-ROOSEVELT', 45157),
#  ('104 ST', 44867),
#  ('190 ST', 44852),
#  ('SUTPHIN BLVD', 44748),
#  ('BEVERLY RD', 44703),
#  ('HOWARD BCH JFK', 44551),
#  ('ST LAWRENCE AV', 44541),
#  ('EASTN PKWY-MUSM', 44415),
#  ('FRANKLIN ST', 44104),
#  ('LAFAYETTE AV', 43606),
#  ('80 ST', 42031),
#  ('RIT-MANHATTAN', 41556),
#  ('163 ST-AMSTERDM', 41492),
#  ('238 ST', 41482),
#  ('NEWARK C', 40270),
#  ('HARLEM 148 ST', 39485),
#  ('BOWERY', 39426),
#  ('FOREST AVE', 39398),
#  ('EASTCHSTER/DYRE', 39320),
#  ('CYPRESS AV', 38605),
#  ('KNICKERBOCKER', 38218),
#  ('65 ST', 37360),
#  ('25 ST', 37250),
#  ('EAST 105 ST', 37041),
#  ('DITMAS AV', 36991),
#  ('74 ST-BROADWAY', 36926),
#  ('75 ST-ELDERTS', 36740),
#  ('PRESIDENT ST', 35621),
#  ('75 AV', 35438),
#  ('BURKE AV', 34520),
#  ('NORWOOD AV', 34453),
#  ('4 AV-9 ST', 34234),
#  ('BAYCHESTER AV', 34121),
#  ('9TH STREET', 33834),
#  ('NEREID AV', 33601),
#  ('219 ST', 33224),
#  ('BUHRE AV', 33179),
#  ('LONGWOOD AV', 33142),
#  ('39 AV', 32959),
#  ('138/GRAND CONC', 32828),
#  ('CENTRAL AV', 32730),
#  ('CLEVELAND ST', 32401),
#  ('LIVONIA AV', 32365),
#  ('SHEPHERD AV', 32331),
#  ('VAN SICLEN AVE', 32161),
#  ('INTERVALE AV', 31930),
#  ('CHAUNCEY ST', 31841),
#  ('BAY 50 ST', 31182),
#  ('BEVERLEY ROAD', 31163),
#  ('LIBERTY AV', 28135),
#  ('AVENUE H', 27838),
#  ('AVENUE N', 27338),
#  ('88 ST', 27254),
#  ('SENECA AVE', 26763),
#  ('BEACH 60 ST', 26003),
#  ('BEACH 67 ST', 25370),
#  ('121 ST', 25237),
#  ('AVENUE X', 24877),
#  ('ZEREGA AV', 24468),
#  ('ALABAMA AV', 24321),
#  ('AVENUE P', 24156),
#  ('HEWES ST', 23186),
#  ('55 ST', 23068),
#  ('METS-WILLETS PT', 22513),
#  ('BRONX PARK EAST', 22324),
#  ('MORRIS PARK', 22057),
#  ('BUSHWICK AV', 21694),
#  ('AQUEDUCT RACETR', 21644),
#  ('W 8 ST-AQUARIUM', 20699),
#  ('BEACH 25 ST', 19404),
#  ('WHITLOCK AV', 18937),
#  ('215 ST', 18684),
#  ('MIDDLETOWN RD', 18515),
#  ('ATLANTIC AV', 17842),
#  ('NEPTUNE AV', 16045),
#  ('AVENUE I', 15525),
#  ('CYPRESS HILLS', 14640),
#  ('21 ST', 13753),
#  ('BOTANIC GARDEN', 12416),
#  ('BEACH 36 ST', 10281),
#  ('AQUEDUCT N.COND', 8958),
#  ("E 143/ST MARY'S", 8655),
#  ('BEACH 90 ST', 8023),
#  ('BEACH 44 ST', 7633),
#  ('TOMPKINSVILLE', 7043),
#  ('ROCKAWAY PARK B', 6368),
#  ('BEACH 98 ST', 4421),
#  ('NEWARK HM HE', 3529),
#  ('BROAD CHANNEL', 2623),
#  ('BEACH 105 ST', 2152)]

# %% [markdown]
# ## Exercise 10
# - Make a single list of these total ridership values and plot it with `plt.hist(total_ridership_counts)` to get an idea about the distribution of total ridership among different stations.
# This should show you that most stations have a small traffic, and the histogram bins for large traffic volumes have small bars.
#
# *Additional Hint*:
# If you want to see which stations take the meat of the traffic, you can sort the total ridership counts and make a `plt.bar` graph. For this, you want to have two lists: the indices of each bar, and the values. The indices can just be `0,1,2,3,...`, so you can do
#
#     indices = range(len(total_ridership_values))
#     plt.bar(indices, total_ridership_values)

# %%
single_list = []
total_riders = []

for pair in sorted_pairs:
    single_list.append(pair[0]) #stations into list
    total_riders.append(pair[1]) #total ridership for each station
    
plt.figure(figsize=(10,7))
plt.hist(total_riders)
plt.title('Frequency Distribution of Each Station')
plt.xlabel('Total Ridership')
plt.ylabel('Frequency')
